# %%
import pandas as pd
import numpy as np

from tqdm.notebook import tqdm

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.neighbors import NearestNeighbors

# %matplotlib inline

# %% [markdown]
# 1. Использовать dataset MovieLens
# 1. Построить рекомендации (регрессия, предсказываем оценку) на фичах:
# - TF-IDF на тегах и жанрах
# - Средние оценки (+ median, variance, etc.) пользователя и фильма
# 3. Оценить RMSE на тестовой выборке

# %%
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-', '').split('|'))

# %%
movies['genres'] = [change_string(g) for g in movies.genres.values]

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies_df = movies.merge(tags, on = 'movieId')
movies_df.drop(['userId', 'timestamp'], axis = 1, inplace=True)
#movies_df = movies_df.merge(ratings)
movies_df
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres               tag
# 0     Adventure Animation Children Comedy Fantasy             pixar
# 1     Adventure Animation Children Comedy Fantasy             pixar
# 2     Adventure Animation Children Comedy Fantasy               fun
# 3                      Adventure Children Fantasy           fantasy
# 4                      Adventure Children Fantasy  magic board game
# ...                                           ...               ...
# 3678              Action Adventure Children SciFi         star wars
# 3679                Action Animation Comedy SciFi             anime
# 3680                Action Animation Comedy SciFi            comedy
# 3681                Action Animation Comedy SciFi           gintama
# 3682                Action Animation Comedy SciFi          remaster
#
# [3683 rows x 4 columns]

# %%
movies_tags = {}

for movie, group in tqdm(movies_df.groupby('title')):
    tags = set([str(s).replace(' ', '').replace('-', '') for s in group.tag.values])
    movies_tags[movie]
# Out:
#   0%|          | 0/1554 [00:00<?, ?it/s]

# %%
movies_tags
# Out:
# {'(500) Days of Summer (2009)': {'Funny',
#   'ZooeyDeschanel',
#   'artistic',
#   'humorous',
#   'inspiring',
#   'intelligent',
#   'quirky',
#   'romance'},
#  '...And Justice for All (1979)': {'lawyers'},
#  '10 Cloverfield Lane (2016)': {'creepy', 'suspense'},
#  '10 Things I Hate About You (1999)': {'Shakespearesortof'},
#  '101 Dalmatians (1996)': {'dogs', 'remake'},
#  '101 Dalmatians (One Hundred and One Dalmatians) (1961)': {'Disney'},
#  '11\'09"01 - September 11 (2002)': {'terrorism'},
#  '12 Angry Men (1957)': {'Motivational',
#   'claustrophobic',
#   'confrontational',
#   'court',
#   'earnest',
#   'gooddialogue',
#   'greatscreenplay',
#   'gritty',
#   'thoughtprovoking'},
#  '127 Hours (2010)': {'stranded'},
#  '13 Going on 30 (2004)': {'MarkRuffalo'},
#  '2001: A Space Odyssey (1968)': {'ArthurC.Clarke',
#   'Dull',
#   'Hal',
#   'Oscar(BestEffectsVisualEffects)',
#   'StanleyKubrick',
#   'aliens',
#   'apes',
#   'artificialintelligence',
#   'atmospheric',
#   'cinematography',
#   'classic',
#   'computer',
#   'confusingending',
#   'cultfilm',
#   'future',
#   'futuristic',
#   'imdbtop250',
#   'masterpiece',
#   'meditative',
#   'music',
#   'mystery',
#   'overrated',
#   'philosophical',
#   'relaxing',
#   'revolutionary',
#   'robots',
#   'scifi',
#   'setting:space/spaceship',
#   'slow',
#   'slowpaced',
#   'soundtrack',
#   'space',
#   'spacecraft',
#   'spacetravel',
#   'superbsoundtrack',
#   'surreal',
#   'technology',
#   'tedious',
#   'visual',
#   'visuallyappealing'},
#  '21 Grams (2003)': {'DEPRESSING'},
#  '25th Hour (2002)': {'crime', 'nightclub'},
#  '28 Days Later (2002)': {'zombies'},
#  '39 Steps, The (1935)': {'fugitive'},
#  '3:10 to Yuma (2007)': {'ChristianBale'},
#  '40-Year-Old Virgin, The (2005)': {'BESTPICTURE',
#   'classic',
#   'hilarious',
#   'stevecarell'},
#  '400 Blows, The (Les quatre cents coups) (1959)': {'emotional',
#   'gentle',
#   'heartwarming',
#   'lyrical',
#   'reflective'},
#  '42 Up (1998)': {'InNetflixqueue', 'Upseries'},
#  '84 Charing Cross Road (1987)': {'books'},
#  '8MM (1999)': {'NicolasCage'},
#  'A Million Ways to Die in the West (2014)': {'CharlizeTheron',
#   'LiamNeeson',
#   'SethMacFarlane',
#   'witty'},
#  'A Pigeon Sat on a Branch Reflecting on Existence (2014)': {'depressing',
#   'understated'},
#  'A Story of Children and Film (2013)': {'filmhistory',
#   'poetic',
#   'representationofchildren'},
#  'A.I. Artificial Intelligence (2001)': {'Bittersweet',
#   'StevenSpielberg',
#   'android(s)/cyborg(s)',
#   'artificialintelligence',
#   'robots'},
#  'About a Boy (2002)': {'NickHornby'},
#  'Accused, The (1988)': {'rape'},
#  "Adam's Rib (1949)": {'HepburnandTracy'},
#  'Addams Family Values (1993)': {'ChristinaRicci',
#   'ChristopherLloyd',
#   'blackcomedy',
#   'darkcomedy',
#   'family',
#   'gothic'},
#  'Addams Family, The (1991)': {'ChristinaRicci',
#   'ChristopherLloyd',
#   'Family',
#   'blackcomedy',
#   'gothic',
#   'quirky'},
#  'Adventures of Priscilla, Queen of the Desert, The (1994)': {'crossdressing',
#   'menindrag',
#   'remade'},
#  'Adventures of Robin Hood, The (1938)': {'swashbuckler'},
#  'African Queen, The (1951)': {'missionary'},
#  'After the Thin Man (1936)': {'NickandNoraCharles'},
#  'Age of Innocence, The (1993)': {'EdithWharton'},
#  'Air Force One (1997)': {'president'},
#  'Airheads (1994)': {'Comedy'},
#  'Airplane! (1980)': {'aviation', 'spoof'},
#  'Akira (1988)': {'animation', 'anime', 'visuallystunning'},
#  'Aladdin (1992)': {'Disney'},
#  'Alfie (1966)': {'sexuality'},
#  'Alice Adams (1935)': {'class'},
#  "Alice Doesn't Live Here Anymore (1974)": {'InNetflixqueue'},
#  'Alice in Wonderland (1951)': {'Disney'},
#  'Alien (1979)': {'aliens'},
#  'Aliens (1986)': {'SPACETRAVEL',
#   'action',
#   'aliens',
#   'horror',
#   'scifi',
#   'space',
#   'spacecraft',
#   'suspense'},
#  'Alive (1993)': {'InNetflixqueue'},
#  'All About Eve (1950)': {'Hollywood'},
#  "All the King's Men (1949)": {'HueyLong',
#   'InNetflixqueue',
#   'RobertPennWarren'},
#  "All the President's Men (1976)": {'DeepThroat', 'Watergate', 'journalism'},
#  'All the Real Girls (2003)': {'adolescence'},
#  'Almost Famous (2000)': {'RollingStone', 'journalism', 'music'},
#  'Amadeus (1984)': {'Mozart', 'Salieri'},
#  "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)": {'whimsical'},
#  'Amen. (2002)': {'InNetflixqueue'},
#  "America's Sweethearts (2001)": {'Hollywood', 'moviebusiness'},
#  'American Gangster (2007)': {'DenzelWashington',
#   'corruption',
#   'mafia',
#   'organizedcrime'},
#  'American History X (1998)': {'edwardnorton',
#   'emotional',
#   'politics',
#   'racism',
#   'thoughtprovoking'},
#  'American Movie (1999)': {'InNetflixqueue'},
#  'American Pie (1999)': {'ChrisKlein',
#   'JasonBiggs',
#   'SeannWilliamScott',
#   'bestcomedy',
#   'dumb',
#   'notfunny',
#   'pizzabeer',
#   'teen'},
#  'American President, The (1995)': {'politics', 'president'},
#  'American Splendor (2003)': {'cancer'},
#  'American in Paris, An (1951)': {'France'},
#  'Americanization of Emily, The (1964)': {'InNetflixqueue'},
#  'Anastasia (1956)': {'InNetflixqueue'},
#  'Anatomy of a Murder (1959)': {'court'},
#  'Anchorman 2: The Legend Continues (2013)': {'SteveCarell',
#   'comedy',
#   'stupidbutfunny',
#   'willferrell'},
#  'Anchorman: The Legend of Ron Burgundy (2004)': {'SteveCarell',
#   'WillFerrell',
#   'awesome',
#   'comedy',
#   'hilarious',
#   'stupid'},
#  'And Then There Were None (1945)': {'InNetflixqueue'},
#  'And the Band Played On (1993)': {'AIDs', 'InNetflixqueue'},
#  'Andalusian Dog, An (Chien andalou, Un) (1929)': {'mindfuck',
#   'surreal',
#   'surrealism'},
#  "Angel's Egg (Tenshi no tamago) (1985)": {'atmospheric',
#   'bizzare',
#   'eerie',
#   'symbolism'},
#  'Angie (1994)': {'pregnancy'},
#  'Animal House (1978)': {'TOGA', 'college'},
#  'Animatrix, The (2003)': {'Matrix',
#   'animation',
#   'anime',
#   'cyberpunk',
#   'dark',
#   'scifi'},
#  'Anna Karenina (1997)': {'Tolstoy'},
#  'Anne Frank Remembered (1995)': {'Holocaust'},
#  'Anne of the Thousand Days (1969)': {'AnneBoleyn'},
#  'Annie Hall (1977)': {'NewYork'},
#  'Another Thin Man (1939)': {'NickandNoraCharles'},
#  'Apartment, The (1960)': {'adultery'},
#  'Apocalypse Now (1979)': {'Vietnam'},
#  'Apollo 13 (1995)': {'NASA', 'moon', 'space'},
#  'Arachnophobia (1990)': {'spiders'},
#  'Argo (2012)': {'Thrilling', 'cia', 'politics'},
#  'Aristocats, The (1970)': {'Disney'},
#  'Armageddon (1998)': {'space'},
#  'Around the World in 80 Days (1956)': {'race'},
#  'Arrival (2016)': {'Cerebral',
#   'beautifulvisuals',
#   'cinematography',
#   'goodcinematography',
#   'smart',
#   'thoughtprovoking',
#   'visuallyappealing'},
#  'Arrival, The (1996)': {'aliens'},
#  'Arsenic and Old Lace (1944)': {'murder'},
#  "Astronaut's Wife, The (1999)": {'aliens'},
#  'Au Hasard Balthazar (1966)': {'donkey'},
#  'Auntie Mame (1958)': {'1920s'},
#  'Avalon (1990)': {'InNetflixqueue'},
#  'Avatar (2009)': {'JamesCameron',
#   'badscience',
#   'beautifulscenery',
#   'futuristic',
#   'graphicdesign',
#   'military',
#   'music',
#   'politics',
#   'poordialogue',
#   'romance',
#   'scifi',
#   'superficialplot',
#   'thoughtprovoking',
#   'toolong',
#   'unoriginal',
#   'visuallystunning',
#   'whiteguilt'},
#  'Avengers, The (2012)': {'CaptainAmerica',
#   'fun',
#   'greathumor',
#   'silly',
#   'superhero',
#   'superheroteam',
#   'visuallyappealing'},
#  'Avengers: Infinity War - Part I (2018)': {'Dark',
#   'Dr.Strange',
#   'Greatvillain',
#   'GuardiansoftheGalaxy',
#   'MCU',
#   'Marvel',
#   'RobertDowneyJr.',
#   'Sad',
#   'Thanos',
#   'Thor',
#   'Visuallyappealing',
#   'Visuallystunning',
#   'comicbook',
#   'emotional'},
#  'Aviator, The (2004)': {'HowardHughes', 'biopic', 'moviebusiness'},
#  'Awful Truth, The (1937)': {'screwball'},
#  'Babadook, The (2014)': {'Metaphorical',
#   'atmospheric',
#   'dark',
#   'psychological'},
#  'Babe (1995)': {'Animalmovie',
#   'pigs',
#   'villainnonexistentornotneededforgoodstory'},
#  'Babel (2006)': {'BradPitt',
#   'cateblanchett',
#   'multiplestorylines',
#   'socialcommentary'},
#  "Babette's Feast (Babettes gæstebud) (1987)": {'Food'},
#  'Babylon 5: In the Beginning (1998)': {'spacestation'},
#  'Bachelor and the Bobby-Soxer, The (1947)': {'court'},
#  'Back to the Future (1985)': {'timetravel'},
#  'Back to the Future Part II (1989)': {'timetravel'},
#  'Bad Day at Black Rock (1955)': {'InNetflixqueue'},
#  'Bad News Bears, The (1976)': {'baseball'},
#  'Bad Seed, The (1956)': {'evilchildren'},
#  'Bad and the Beautiful, The (1952)': {'moviebusiness'},
#  'Ballad of Jack and Rose, The (2005)': {'fatherhood'},
#  'Bank Job, The (2008)': {'heist', 'robbery', 'smalltimecriminals'},
#  'Barton Fink (1991)': {'moviebusiness'},
#  'Basketball Diaries, The (1995)': {'LeonardoDiCaprio',
#   'MarkWahlberg',
#   'addiction',
#   'heroin'},
#  'Batman (1989)': {'superhero'},
#  'Batman Forever (1995)': {'superhero'},
#  'Batman Returns (1992)': {'superhero'},
#  'Batman v Superman: Dawn of Justice (2016)': {'GalGadot',
#   'action',
#   'batman',
#   'benaffleck',
#   'dark',
#   'dccomics',
#   'superhero',
#   'superman',
#   'wonderwoman'},
#  'Battle Royale (Batoru rowaiaru) (2000)': {'basedonabook',
#   'bloody',
#   'brutal',
#   'controversial',
#   'dystopia',
#   'goretastic',
#   'satire',
#   'socialcommentary',
#   'survival',
#   'violence'},
#  'Battle of Algiers, The (La battaglia di Algeri) (1966)': {'InNetflixqueue'},
#  'Beasts of No Nation (2015)': {'Moving'},
#  'Beasts of the Southern Wild (2012)': {'Beautiful', 'emotional', 'poetic'},
#  'Beat the Devil (1953)': {'crime'},
#  'Beautiful Mind, A (2001)': {'mathematics'},
#  'Beauty and the Beast (1991)': {'Disney'},
#  'Before Sunrise (1995)': {'generationX'},
#  'Before Sunset (2004)': {'generationX'},
#  'Begotten (1990)': {'boring', 'psychedelic', 'symbolic'},
#  'Being Julia (2004)': {'stage'},
#  'Being There (1979)': {'television'},
#  'Believer, The (2001)': {'Judaism', 'antiSemitism'},
#  'Bend It Like Beckham (2002)': {'soccer'},
#  'Benny & Joon (1993)': {'NotSeen', 'mentalillness'},
#  'Best in Show (2000)': {'Dogs', 'satire'},
#  'Better Luck Tomorrow (2002)': {'gangs'},
#  'Better Off Dead... (1985)': {'skiing'},
#  'Beyond Silence (Jenseits der Stille) (1996)': {'InNetflixqueue'},
#  'Big (1988)': {'children'},
#  'Big Business (1988)': {'twins'},
#  'Big Daddy (1999)': {'AdamSandler'},
#  'Big Eyes (2014)': {'painter'},
#  'Big Fish (2003)': {'TimBurton', 'dreamlike', 'sentimental', 'surreal'},
#  'Big Hero 6 (2014)': {'animation',
#   'feelgood',
#   'funfamilymovie',
#   'kids',
#   'robots',
#   'veryfunny'},
#  'Big Kahuna, The (2000)': {'business', 'religion'},
#  'Big Lebowski, The (1998)': {'CoenBrothers',
#   'Cultclassic',
#   'Highlyquotable',
#   'JeffBridges',
#   'JohnGoodman',
#   'JulianneMoore',
#   'Nudity(FullFrontal)',
#   'PhilipSeymourHoffman',
#   'SteveBuscemi',
#   'blackcomedy',
#   'bowling',
#   'classic',
#   'coenbrothers',
#   'comedy',
#   'crime',
#   'cultfilm',
#   'darkcomedy',
#   'deadpan',
#   'drugs',
#   'funny',
#   'greatdialogue',
#   'greatsoundtrack',
#   'imdbtop250',
#   'kidnapping',
#   'marijuana',
#   'offbeatcomedy',
#   'quirky',
#   'ransom',
#   'rug',
#   'sarcasm',
#   'satirical',
#   'violence'},
#  'Big Night (1996)': {'food'},
#  'Big Short, The (2015)': {'Witty', 'funny', 'interesting'},
#  'Big Sleep, The (1946)': {'Hammett'},
#  'Big Top Pee-Wee (1988)': {'circus'},
#  "Bill & Ted's Bogus Journey (1991)": {'timetravel'},
#  "Bill & Ted's Excellent Adventure (1989)": {'timetravel'},
#  'Bill Cosby, Himself (1983)': {'StandUp'},
#  'Billabong Odyssey (2003)': {'bigwave', 'surfing'},
#  'Billy Elliot (2000)': {'ballet'},
#  'Billy Madison (1995)': {'AdamSandler', 'school', 'stoplookingatmeswan'},
#  'Birdman of Alcatraz (1962)': {'birds', 'prison'},
#  'Birds, The (1963)': {'birds'},
#  "Bishop's Wife, The (1947)": {'Christmas'},
#  'Black Beauty (1994)': {'horses'},
#  'Black Mirror: White Christmas (2014)': {'Dystopia',
#   'future',
#   'interesting',
#   'jonhamm',
#   'thoughtprovoking'},
#  'Black Narcissus (1947)': {'convent', 'religion'},
#  'Black Orpheus (Orfeu Negro) (1959)': {'InNetflixqueue'},
#  'Black Robe (1991)': {'InNetflixqueue'},
#  'Black Stallion, The (1979)': {'horses'},
#  'Black Swan (2010)': {'alterego',
#   'atmospheric',
#   'creepy',
#   'horror',
#   'obsession',
#   'surreal'},
#  'Blade (1998)': {'vampires'},
#  'Blade II (2002)': {'Greatmovie', 'WesleySnipes'},
#  'Blade Runner (1982)': {'PhilipK.Dick',
#   'androids',
#   'artificialintelligence',
#   'atmospheric',
#   'cyberpunk',
#   'dreamlike',
#   'existentialism',
#   'future',
#   'mindfuck',
#   'philosophical',
#   'robots',
#   'scifi'},
#  'Blade Runner 2049 (2017)': {'atmospheric',
#   'beautiful',
#   'cinematography',
#   'dark',
#   'dreamlike',
#   'existentialism',
#   'moody',
#   'philosophical'},
#  'Blair Witch Project, The (1999)': {'claimstobetrue', 'video'},
#  'Blazing Saddles (1974)': {'darkhumor', 'easygoing', 'silly'},
#  'Blood Diamond (2006)': {'Africa',
#   'JenniferConnelly',
#   'LeonardoDiCaprio',
#   'corruption',
#   'justice'},
#  'Blood Simple (1984)': {'CoenBrothers'},
#  'Blue Angel, The (Blaue Engel, Der) (1930)': {'nightclub', 'singers'},
#  'Blue Car (2002)': {'teachers'},
#  'Blue Sky (1994)': {'Oscar(BestActress)', 'mentalillness'},
#  'Blue Velvet (1986)': {'sexuality', 'suburbia'},
#  'Blues Brothers, The (1980)': {'SaturdayNightLive'},
#  'Bob Roberts (1992)': {'politics'},
#  'Bonnie and Clyde (1967)': {'1920s', 'gangsters'},
#  'Boomerang (1992)': {'dating'},
#  'Boot, Das (Boat, The) (1981)': {'submarine'},
#  'Born Free (1966)': {'animalmovie', 'lions'},
#  'Born Yesterday (1950)': {'remade'},
#  'Born into Brothels (2004)': {'India'},
#  'Bottle Rocket (1996)': {'crime', 'offbeatcomedy', 'quirky'},
#  'Bourne Ultimatum, The (2007)': {'RobertLudlum',
#   'assassin',
#   'assassinintraining(scene)',
#   'espionage'},
#  'Bowling for Columbine (2002)': {'violenceinamerica'},
#  'Boy in the Striped Pajamas, The (Boy in the Striped Pyjamas, The) (2008)': {'childishnaivity',
#   'friendship'},
#  'Brandon Teena Story, The (1998)': {'sexuality'},
#  'Brassed Off (1996)': {'InNetflixqueue'},
#  'Braveheart (1995)': {'Medieval',
#   'Oscar(BestCinematography)',
#   'Scotland',
#   'beautifulscenery',
#   'epic',
#   'historical',
#   'inspirational',
#   'melgibson',
#   'revenge',
#   'swordfight'},
#  'Breaker Morant (1980)': {'court'},
#  "Breakfast at Tiffany's (1961)": {'Capote'},
#  'Breakfast on Pluto (2005)': {'transvestite'},
#  'Breaking the Waves (1996)': {'religion'},
#  'Bridge on the River Kwai, The (1957)': {'POW'},
#  "Bridget Jones's Diary (2001)": {'singletons'},
#  'Brief Encounter (1946)': {'adultery'},
#  'Bringing Up Baby (1938)': {'leopard', 'screwball'},
#  'Broadcast News (1987)': {'journalism'},
#  'Broadway Danny Rose (1984)': {'showbusiness'},
#  'Broken Flowers (2005)': {'InNetflixqueue'},
#  'Brothers Bloom, The (2008)': {'AdrienBrody',
#   'MarkRuffalo',
#   'RachelWeisz',
#   'conartists',
#   'funny',
#   'interestingcharacters'},
#  'Bruce Almighty (2003)': {'classic', 'religion'},
#  'Buena Vista Social Club (1999)': {'InNetflixqueue'},
#  "Buffalo '66 (a.k.a. Buffalo 66) (1998)": {'avantgarderomanticcomedy',
#   'elegiac',
#   'melancholy',
#   'quirky',
#   'wry'},
#  'Bug (2007)': {'Insanity',
#   'PTSD',
#   'basedonaplay',
#   'conspiracytheory',
#   'creepy',
#   'paranoia'},
#  "Bug's Life, A (1998)": {'Pixar'},
#  'Burn After Reading (2008)': {'BradPitt',
#   'CoenBros',
#   'CoenBrothers',
#   'GeorgeClooney',
#   'JohnMalkovich',
#   'darkcomedy',
#   'espionage',
#   'satire',
#   'twists&turns',
#   'weird'},
#  'Butch Cassidy and the Sundance Kid (1969)': {'crime'},
#  'Butterflies Are Free (1972)': {'blind'},
#  'Caddyshack (1980)': {'golf'},
#  'Caine Mutiny, The (1954)': {'military'},
#  'Camelot (1967)': {'KingArthur'},
#  'Candidate, The (1972)': {'politics'},
#  'Cannonball Run, The (1981)': {'race'},
#  'Cape Fear (1962)': {'lawyer'},
#  'Cape Fear (1991)': {'JulietteLewis',
#   'MartinScorsese',
#   'RobertDeNiro',
#   'horror',
#   'remake'},
#  'Capote (2005)': {'TrumanCapote'},
#  'Captain Blood (1935)': {'swashbuckler'},
#  'Captain Fantastic (2016)': {'ViggoMortensen',
#   'buildingafamily',
#   'creative',
#   'freedom',
#   'goodwriting',
#   'individualism'},
#  'Captain Phillips (2013)': {'hostage', 'ocean', 'suspense', 'tense'},
#  'Capturing the Friedmans (2003)': {'childabuse'},
#  "Carlito's Way (1993)": {'AlPacino', 'gangster', 'mafia'},
#  'Carrie (1976)': {'StephenKing', 'highschool', 'prom'},
#  'Casablanca (1942)': {'startofabeautifulfriendship'},
#  'Casino (1995)': {'Mafia'},
#  'Cat People (1942)': {'sexuality'},
#  'Cat Returns, The (Neko no ongaeshi) (2002)': {'InNetflixqueue'},
#  'Cat Soup (Nekojiru-so) (2001)': {'abstract',
#   'dark',
#   'psychedelic',
#   'surreal'},
#  'Cat on a Hot Tin Roof (1958)': {'TennesseeWilliams'},
#  "Cat's Eye (1985)": {'StephenKing'},
#  'Catch Me If You Can (2002)': {'LeonardoDiCaprio',
#   'TomHanks',
#   'cheating',
#   'crime',
#   'intelligent',
#   'lies',
#   'smart',
#   'twists&turns'},
#  "Caveman's Valentine, The (2001)": {'NewYork', 'homeless'},
#  'Celebration, The (Festen) (1998)': {'InNetflixqueue'},
#  'Central Station (Central do Brasil) (1998)': {'SouthAmerica'},
#  'Chain Reaction (1996)': {'seenatthecinema'},
#  'Chamber, The (1996)': {'JohnGrisham', 'deathpenalty'},
#  'Changeling (2008)': {'emotional'},
#  'Chaplin (1992)': {'InNetflixqueue', 'biopic'},
#  'Charade (1963)': {'heist'},
#  'Chariots of Fire (1981)': {'Olympics', 'sports'},
#  'Charlie and the Chocolate Factory (2005)': {'roalddahl'},
#  'Chicago (2002)': {'court', 'jazz', 'murder'},
#  'Children of Heaven, The (Bacheha-Ye Aseman) (1997)': {'InNetflixqueue'},
#  'Children of a Lesser God (1986)': {'deathpenalty'},
#  'Children of the Corn (1984)': {'StephenKing'},
#  'Children of the Damned (1963)': {'evilchildren'},
#  'Chinatown (1974)': {'incest'},
#  'Christine (1983)': {'StephenKing'},
#  'Christmas Story, A (1983)': {'Christmas'},
#  "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)": {'christmas'},
#  'Chronicles of Narnia: Prince Caspian, The (2008)': {'TildaSwinton',
#   'fantasy',
#   'lion',
#   'narnia'},
#  'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)': {'C.S.Lewis'},
#  'Cinderella (1950)': {'Disney'},
#  'Cinderella Man (2005)': {'boksdrama', 'boxing'},
#  'Cinemania (2002)': {'movies'},
#  'Circle of Friends (1995)': {'Ireland'},
#  'Circus, The (1928)': {'bigtop', 'circus'},
#  'Citizen Kane (1941)': {'Rosebud'},
#  'City Lights (1931)': {'blind'},
#  'City of God (Cidade de Deus) (2002)': {'crime',
#   'multiplestorylines',
#   'notseen',
#   'photography',
#   'truestory',
#   'violence'},
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)': {'kidnapping'},
#  'Clear and Present Danger (1994)': {'TomClancy'},
#  'Clerks (1994)': {'cynical',
#   'generationX',
#   'hilarious',
#   'independentfilm',
#   'quirky',
#   'witty'},
#  'Client, The (1994)': {'JohnGrisham'},
#  'Clockwork Orange, A (1971)': {'brainwashing'},
#  'Clueless (1995)': {'Emma',
#   'JaneAusten',
#   'PaulRudd',
#   'chickflick',
#   'funny',
#   'quotable',
#   'seenmorethanonce'},
#  "Coal Miner's Daughter (1980)": {'LorettaLynn'},
#  'Cold Comfort Farm (1995)': {'InNetflixqueue'},
#  'Cold Mountain (2003)': {'CivilWar'},
#  'College (1927)': {'InNetflixqueue'},
#  'Come Back, Little Sheba (1952)': {'alcoholism', 'marriage'},
#  'Come and See (Idi i smotri) (1985)': {'atmospheric',
#   'bleak',
#   'disturbing',
#   'gritty',
#   'harsh'},
#  'Coming Home (1978)': {'Vietnam'},
#  'Coming to America (1988)': {'Africa', 'immigrants'},
#  'Commitments, The (1991)': {'InNetflixqueue'},
#  'Confessions of a Dangerous Mind (2002)': {'television'},
#  'Congo (1995)': {'MichaelCrichton'},
#  'Constant Gardener, The (2005)': {'Africa', 'business', 'politics'},
#  'Control Room (2004)': {'journalism'},
#  'Conversation, The (1974)': {'spying'},
#  "Cookie's Fortune (1999)": {'southernUS'},
#  'Cool Hand Luke (1967)': {'prison'},
#  'Copycat (1995)': {'serialkiller'},
#  'Coraline (2009)': {'Surreal',
#   'TimBurton',
#   'claymation',
#   'creepy',
#   'dark',
#   'darkfairytale'},
#  'Corpse Bride (2005)': {'06OscarNominatedBestMovieAnimation',
#   'JohnnyDepp',
#   'TimBurton',
#   'animation',
#   'gothic',
#   'helenabonhamcarter',
#   'visuallyappealing'},
#  'Corrina, Corrina (1994)': {'interracialromance'},
#  'Country Girl, The (1954)': {'Oscar(BestActress)'},
#  'Courage Under Fire (1996)': {'GulfWar'},
#  'Cowboy Bebop: The Movie (Cowboy Bebop: Tengoku no Tobira) (2001)': {'amazingartwork',
#   'anime',
#   'scifi'},
#  'Crash (2004)': {'racism'},
#  'Creature Comforts (1989)': {'aardman'},
#  'Crimson Tide (1995)': {'submarine'},
#  'Crocodile Dundee (1986)': {'Australia'},
#  'Crocodile Dundee II (1988)': {'Australia'},
#  'Croods, The (2013)': {'animation', 'funny', 'stoneage'},
#  'Crossfire (1947)': {'antiSemitism'},
#  'Crossing Delancey (1988)': {'NewYork'},
#  'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)': {'china',
#   'martialarts'},
#  'Crucible, The (1996)': {'ArthurMiller'},
#  'Crumb (1994)': {'InNetflixqueue'},
#  'Cry in the Dark, A (1988)': {'Australia', 'adingoatemybaby'},
#  'Cry, the Beloved Country (1995)': {'InNetflixqueue', 'SouthAfrica'},
#  'Cujo (1983)': {'StephenKing'},
#  'Cutting Edge, The (1992)': {'figureskating'},
#  'Cyrano de Bergerac (1990)': {'InNetflixqueue'},
#  'Da Vinci Code, The (2006)': {'AudreyTautou',
#   'Mystery',
#   'Paris',
#   'TomHanks',
#   'adventure',
#   'conspiracytheory',
#   'treasurehunt'},
#  'Dallas Buyers Club (2013)': {'JaredLeto', 'socialcommentary', 'uplifting'},
#  'Dancer in the Dark (2000)': {'blindness', 'factory'},
#  'Dances with Wolves (1990)': {'AmericanIndians', 'NativeAmericans'},
#  'Dangerous Liaisons (1988)': {'adultery'},
#  'Dangerous Minds (1995)': {'highschool', 'teacher'},
#  'Danny Deckchair (2003)': {'Australia'},
#  'Daredevil (2003)': {'BenAffleck', 'bad'},
#  'Dark City (1998)': {'amnesia'},
#  'Dark Days (2000)': {'Amtrak',
#   'Homeless',
#   'NewYork',
#   'Sundanceawardwinner',
#   'Train',
#   'independent'},
#  'Dark Knight Rises, The (2012)': {'AnneHathaway',
#   'ChristianBale',
#   'ChristopherNolan',
#   'MorganFreeman',
#   'comicbook',
#   'greatending',
#   'politicalcommentary',
#   'superhero'},
#  'Dark Knight, The (2008)': {'dark', 'gritty', 'psychology', 'superhero'},
#  'Dark Passage (1947)': {'amnesia'},
#  'Dark Victory (1939)': {'terminalillness'},
#  'Dark Water (Honogurai mizu no soko kara) (2002)': {'remade'},
#  'Dave (1993)': {'President'},
#  'Day of the Jackal, The (1973)': {'assassination'},
#  'Day the Earth Stood Still, The (1951)': {'aliens'},
#  'Days of Wine and Roses (1962)': {'alcoholism'},
#  'Dead Again (1991)': {'memory', 'music'},
#  'Dead Man Walking (1995)': {'Nun', 'deathpenalty'},
#  'Dead Poets Society (1989)': {'HighSchool', 'highschool'},
#  'Dead Zone, The (1983)': {'StephenKing'},
#  'Deadpool 2 (2018)': {'JoshBrolin', 'RyanReynolds', 'sarcasm'},
#  'Dear Frankie (2004)': {'Ireland'},
#  'Death Becomes Her (1992)': {'plasticsurgery'},
#  'Decade Under the Influence, A (2003)': {'1970s', 'movies'},
#  'Deer Hunter, The (1978)': {'Vietnam'},
#  'Defiant Ones, The (1958)': {'racism'},
#  'Definitely, Maybe (2008)': {'RachelWeisz', 'RyanReynolds'},
#  'Deliver Us from Evil (2006)': {'thecatholicchurchisthemostcorruptorganizationinhistory'},
#  'Deliverance (1972)': {'river'},
#  'Departed, The (2006)': {'JackNicholson',
#   'LeonardoDiCaprio',
#   'MartinScorsese',
#   'atmospheric',
#   'suspense',
#   'twistending',
#   'undercovercop',
#   'waytoolong'},
#  'Desk Set (1957)': {'HepburnandTracy'},
#  "Devil's Backbone, The (Espinazo del diablo, El) (2001)": {'ghosts'},
#  "Devil's Playground (2002)": {'Amish'},
#  "Devil's Rejects, The (2005)": {'RobZombie'},
#  "Diary of a Country Priest (Journal d'un curé de campagne) (1951)": {'priest',
#   'religion'},
#  'Dick Tracy (1990)': {'comicbook'},
#  'Dirty Dancing (1987)': {'dance', 'music'},
#  'Dirty Pretty Things (2002)': {'immigration'},
#  'District 9 (2009)': {'intelligentscifi'},
#  'Divergent (2014)': {'antiintellectual',
#   'badwriting',
#   'dystopia',
#   'newsociety',
#   'plotholes',
#   'predictable',
#   'scifi',
#   'unintelligent'},
#  'Divided We Fall (Musíme si pomáhat) (2000)': {'Holocaust'},
#  'Divorcee, The (1930)': {'divorce'},
#  'Django Unchained (2012)': {'ChristophWaltz',
#   'Greatperformances',
#   'Humour',
#   'LeonardoDiCaprio',
#   'QuentinTarantino',
#   'SamuelL.Jackson',
#   'Soundtrack',
#   'action',
#   'funny',
#   'goodsoundtrack',
#   'western'},
#  'Do the Right Thing (1989)': {'greatcinematography', 'racism'},
#  'Doctor Strange (2016)': {'visuallyappealing'},
#  'Dogfight (1991)': {'InNetflixqueue'},
#  'Dogma (1999)': {'KevinSmith',
#   'irreverent',
#   'jayandsilentbob',
#   'religion',
#   'satire'},
#  'Dogville (2003)': {'Grace'},
#  'Dolores Claiborne (1995)': {'StephenKing'},
#  'Don Juan DeMarco (1995)': {'mentalillness', 'psychology'},
#  "Don't Breathe (2016)": {'intense'},
#  'Donnie Brasco (1997)': {'Mafia'},
#  'Donnie Darko (2001)': {'atmospheric',
#   'cerebral',
#   'cultfilm',
#   'dreamlike',
#   'enigmatic',
#   'hallucinatory',
#   'jakegyllenhaal',
#   'mentalillness',
#   'mindfuck',
#   'philosophy',
#   'psychological',
#   'psychology',
#   'quirky',
#   'socialcommentary',
#   'surreal',
#   'teen',
#   'thoughtprovoking',
#   'timetravel',
#   'weird'},
#  'Doors, The (1991)': {'1960s', 'JimMorrison', 'music'},
#  'Double Indemnity (1944)': {'Insurance'},
#  'Double Life, A (1947)': {'Othello'},
#  'Down and Out in Beverly Hills (1986)': {'homeless'},
#  'Down with Love (2003)': {'EwanMcGregor', 'ReneeZellweger', 'retro'},
#  "Dr. Horrible's Sing-Along Blog (2008)": {'NathanFillion',
#   'NeilPatrickHarris',
#   'josswhedon',
#   'parody'},
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)': {'Atomicbomb',
#   'Quirky',
#   'SlimPickens',
#   'blackcomedy',
#   'darkcomedy',
#   'purityofessence',
#   'satire'},
#  'Dream for an Insomniac (1996)': {'generationX'},
#  'Dresser, The (1983)': {'InNetflixqueue'},
#  'Driving Miss Daisy (1989)': {'rasicm'},
#  "Dude, Where's My Car? (2000)": {'bad'},
#  'Duel (1971)': {'InNetflixqueue'},
#  'Duma (2005)': {'Animalmovie', 'InNetflixqueue'},
#  'Dumbo (1941)': {'Disney'},
#  'Dummy (2002)': {'vertriloquism'},
#  'Dunkirk (2017)': {'brilliant', 'inspiring', 'tense'},
#  'E.T. the Extra-Terrestrial (1982)': {'aliens'},
#  'Eat Drink Man Woman (Yin shi nan nu) (1994)': {'InNetflixqueue'},
#  'Ed Wood (1994)': {'moviebusiness'},
#  'Educating Rita (1983)': {'InNetflixqueue'},
#  'Edward Scissorhands (1990)': {'freaks'},
#  'Elephant (2003)': {'adolescence', 'violenceinamerica'},
#  'Elephant Man, The (1980)': {'freaks'},
#  'Elf (2003)': {'christmas'},
#  'Elite Squad (Tropa de Elite) (2007)': {'Favelas'},
#  'Elizabeth (1998)': {'England'},
#  'Elmer Gantry (1960)': {'preacher', 'religion'},
#  'Emma (1996)': {'JaneAusten'},
#  'Enchanted April (1992)': {'Italy'},
#  'End of the Affair, The (1999)': {'GrahamGreene'},
#  'Enemy at the Gates (2001)': {'EdHarris',
#   'JudeLaw',
#   'RachelWeisz',
#   'WorldWarII',
#   'sniper'},
#  'English Patient, The (1996)': {'adultery'},
#  'Enigma (2001)': {'WorldWarII'},
#  'Enron: The Smartest Guys in the Room (2005)': {'business',
#   'money',
#   'scandal'},
#  'Eraserhead (1977)': {'Atmospheric',
#   'InNetflixqueue',
#   'Insane',
#   'arthouse',
#   'creepy',
#   'cryptic',
#   'dark',
#   'disturbing',
#   'dreamlike',
#   'enigmatic',
#   'fuckedup',
#   'gruesome',
#   'hallucinatory',
#   'paranoid',
#   'strange',
#   'surreal',
#   'weird'},
#  'Erin Brockovich (2000)': {'scandal', 'truestory'},
#  'Eternal Sunshine of the Spotless Mind (2004)': {'JimCarrey',
#   'alternatereality',
#   'arthouse',
#   'artistic',
#   'atmospheric',
#   'beautiful',
#   'bittersweet',
#   'colourful',
#   'comedy',
#   'cultfilm',
#   'dreamlike',
#   'emotional',
#   'feelgood',
#   'happpiness',
#   'humane',
#   'imagination',
#   'insightful',
#   'intelligent',
#   'jimcarrey',
#   'love',
#   'lovely',
#   'melancholy',
#   'memory',
#   'mindbending',
#   'philosophy',
#   'quirky',
#   'quirkyromantic',
#   'romantic',
#   'surreal',
#   'surrealism',
#   'thoughtprovoking'},
#  'Europa Europa (Hitlerjunge Salomon) (1990)': {'Holocaust', 'WorldWarII'},
#  'Everest (1998)': {'InNetflixqueue'},
#  'Everybody Wants Some (2016)': {"80's"},
#  'Everything Is Illuminated (2005)': {'InNetflixqueue'},
#  'Evil Dead, The (1981)': {'zombies'},
#  'Evita (1996)': {'AndrewLloydWeber'},
#  'Evolution (2001)': {'SeannWilliamScott', 'reallybad'},
#  'Excalibur (1981)': {'England', 'KingArthur'},
#  'Exorcist, The (1973)': {'demons'},
#  'Eye in the Sky (2016)': {'suspense', 'thoughtprovoking'},
#  'Eye, The (Gin gwai) (Jian gui) (2002)': {'transplants'},
#  'Eyes Wide Shut (1999)': {'sexuality'},
#  'Eyes of Tammy Faye, The (2000)': {'InNetflixqueue', 'televangelist'},
#  'FLCL (2000)': {'2Danimation', 'cultfilm', 'stylish', 'surreal'},
#  'Face/Off (1997)': {'transplants'},
#  'Fahrenheit 451 (1966)': {'RayBradbury'},
#  'Fahrenheit 9/11 (2004)': {'politics', 'terrorism'},
#  'Fantasia (1940)': {'Disney'},
#  'Fantastic Four (2005)': {'ChrisEvans',
#   'JessicaAlba',
#   'comicbook',
#   'heroineintightsuit',
#   'sexyfemalescientist',
#   'superhero'},
#  'Fantastic Four: Rise of the Silver Surfer (2007)': {'ChrisEvans',
#   'JessicaAlba',
#   'Marvel',
#   'badacting',
#   'badjokes',
#   'badplot',
#   'sexyfemalescientist'},
#  'Far and Away (1992)': {'Ireland'},
#  'Far from Heaven (2002)': {'salutetoDouglasSirk'},
#  'Farewell to Arms, A (1932)': {'Hemingway'},
#  'Fargo (1996)': {'CoenBrothers',
#   'KIDNAPPING',
#   'SteveBuscemi',
#   'basedonatruestory',
#   'darkcomedy'},
#  'Fast Times at Ridgemont High (1982)': {'highschool'},
#  'Fatal Attraction (1987)': {'adultery'},
#  'Father of the Bride (1950)': {'wedding'},
#  'Father of the Bride (1991)': {'remake', 'wedding'},
#  'Father of the Bride Part II (1995)': {'pregnancy', 'remake'},
#  'Faust (1926)': {'InNetflixqueue'},
#  'Femme Nikita, La (Nikita) (1990)': {'hitmen'},
#  "Ferris Bueller's Day Off (1986)": {'HighSchool'},
#  'Few Good Men, A (1992)': {'court', 'military'},
#  'Fiddler on the Roof (1971)': {'Judaism', 'Tradition!'},
#  'Fido (2006)': {'zombies'},
#  'Field of Dreams (1989)': {'baseball'},
#  'Fight Club (1999)': {'BradPitt',
#   'ChuckPalahniuk',
#   'DavidFincher',
#   'EdwardNorton',
#   'Nudity(Topless)',
#   'Palahnuik',
#   'TERRORISM',
#   'action',
#   'atmospheric',
#   'basedonabook',
#   'challenging',
#   'classic',
#   'clever',
#   'complicated',
#   'consumerism',
#   'crime',
#   'dark',
#   'darkcomedy',
#   'disturbing',
#   'doublelife',
#   'fighting',
#   'greatacting',
#   'helenabonhamcarter',
#   'imaginaryfriend',
#   'imdbtop250',
#   'mentalillness',
#   'mindblowing',
#   'mindfuck',
#   'narrated',
#   'philosophical',
#   'philosophy',
#   'postmodern',
#   'powerfulending',
#   'psychological',
#   'psychologicalthriller',
#   'psychology',
#   'quirky',
#   'satirical',
#   'schizophrenia',
#   'socialcommentary',
#   'societalcriticism',
#   'stylized',
#   'surreal',
#   'thoughtprovoking',
#   'twist',
#   'twistending',
#   'violence',
#   'violent'},
#  'Final Destination 2 (2003)': {'sequel', 'violent'},
#  'Final Fantasy: The Spirits Within (2001)': {'scifi'},
#  'Finding Forrester (2000)': {'writing'},
#  'Finding Nemo (2003)': {'Disney', 'fish', 'heartwarming'},
#  'Finding Neverland (2004)': {'PeterPan'},
#  'Firm, The (1993)': {'JohnGrisham'},
#  'First Wives Club, The (1996)': {'adultery'},
#  'Fish Called Wanda, A (1988)': {'fish'},
#  'Fisher King, The (1991)': {'homeless'},
#  'Fistful of Dollars, A (Per un pugno di dollari) (1964)': {'bad'},
#  'Flawless (1999)': {'menindrag'},
#  'Fly Away Home (1996)': {'Animalmovie'},
#  'Flying Down to Rio (1933)': {'AstaireandRogers'},
#  'Fog of War: Eleven Lessons from the Life of Robert S. McNamara, The (2003)': {'Vietnam'},
#  'Follow the Fleet (1936)': {'AstaireandRogers'},
#  'Following (1998)': {'ChristopherNolan',
#   'TwistEnding',
#   'blackandwhite',
#   'directorialdebut',
#   'mindfuck',
#   'notlinear'},
#  'Forbidden Kingdom, The (2008)': {'jackiechan', 'kungfu'},
#  'Forbidden Planet (1956)': {'Shakespearesortof', 'space'},
#  'Foreign Correspondent (1940)': {'Europe', 'journalism', 'war'},
#  'Forget Paris (1995)': {'France', 'basketball', 'infertility'},
#  'Forrest Gump (1994)': {'Vietnam',
#   'bittersweet',
#   'bubbagumpshrimp',
#   'emotional',
#   'heartwarming',
#   'lieutenantdan',
#   'shrimp',
#   'stupidisasstupiddoes',
#   'touching'},
#  'Four Weddings and a Funeral (1994)': {'wedding'},
#  'Fox and the Hound, The (1981)': {'Disney'},
#  'Fracture (2007)': {'AnthonyHopkins', 'courtroomdrama', 'twistending'},
#  'Frailty (2001)': {'religion'},
#  'Frank (2014)': {'Eccentric',
#   'adorable',
#   'blackcomedy',
#   'introspection',
#   'mentalillness',
#   'quirky'},
#  'Frankenstein (1931)': {'InNetflixqueue'},
#  'Freaks (1932)': {'circus'},
#  'French Connection, The (1971)': {'drugs', 'police'},
#  'Frida (2002)': {'art'},
#  'Friday the 13th Part 2 (1981)': {'Jason'},
#  'Friday the 13th Part 3: 3D (1982)': {'Jason'},
#  'Friday the 13th Part IV: The Final Chapter (1984)': {'Jason'},
#  'Friday the 13th Part V: A New Beginning (1985)': {'Jason'},
#  'Friday the 13th Part VI: Jason Lives (1986)': {'Jason'},
#  'Friendly Persuasion (1956)': {'Quakers'},
#  'Friends with Benefits (2011)': {'HOTactress',
#   'JustinTimberlake',
#   'MilaKunis',
#   'NewYorkCity',
#   'comedy',
#   'funny',
#   'happyending',
#   'romance',
#   'sex'},
#  'Fugitive, The (1993)': {'basedonaTVshow'},
#  'Full Metal Jacket (1987)': {'Vietnam', 'antiwar'},
#  'Funny Games U.S. (2007)': {'dark',
#   'darkhumor',
#   'intelligent',
#   'thoughtprovoking'},
#  'Funny Thing Happened on the Way to the Forum, A (1966)': {'Rome'},
#  'Fury (1936)': {'revenge'},
#  'G.I. Jane (1997)': {'military'},
#  'Galaxy Quest (1999)': {'spoof'},
#  'Gallipoli (1981)': {'WorldWarI'},
#  'Game Night (2018)': {'Comedy', 'RachelMcAdams', 'funny'},
#  'Game, The (1997)': {'Mystery',
#   'mindfuck',
#   'plottwist',
#   'psychological',
#   'suspense',
#   'twistending'},
#  'Gandhi (1982)': {'India'},
#  'Garden State (2004)': {'psychology'},
#  'Gaslight (1944)': {'Brooch'},
#  'Gattaca (1997)': {'future', 'intelligent', 'thoughtprovoking'},
#  'Gay Divorcee, The (1934)': {'divorce'},
#  "Gentleman's Agreement (1947)": {'Judaism', 'antiSemitism'},
#  'Gentlemen Broncos (2009)': {'badhumor'},
#  'Gentlemen Prefer Blondes (1953)': {'InNetflixqueue'},
#  'Georgy Girl (1966)': {'pregnancy'},
#  'Get Shorty (1995)': {'Hollywood'},
#  'Get Smart (2008)': {'AnneHathaway', 'SteveCarell'},
#  'Ghost (1990)': {'overrated'},
#  'Ghost World (2001)': {'adolescence'},
#  'Ghost and Mrs. Muir, The (1947)': {'ghosts'},
#  'Ghostbusters (a.k.a. Ghost Busters) (1984)': {'ghosts'},
#  'Ghostbusters II (1989)': {'Ghosts'},
#  'Ghosts of the Abyss (2003)': {'Titanic'},
#  'Gia (1998)': {'drugs', 'lesbian'},
#  'Giant (1956)': {'oil'},
#  'Gigantic (A Tale of Two Johns) (2002)': {'InNetflixqueue',
#   'TheyMightBeGiants'},
#  'Gigi (1958)': {'prostitution'},
#  'Gilda (1946)': {'nightclub'},
#  'Ginger Snaps (2000)': {'werewolf'},
#  'Gintama: The Movie (2010)': {'anime', 'comedy', 'gintama', 'remaster'},
#  'Girl, Interrupted (1999)': {'BrittanyMurphy',
#   'MentalHospital',
#   'asylum',
#   'basedonatruestory',
#   'psychology',
#   'winonaryder'},
#  'Gladiator (2000)': {'Epic',
#   'Romans',
#   'Rome',
#   'RussellCrowe',
#   'ancientRome',
#   'history',
#   'imdbtop250',
#   'revenge'},
#  'Glass Menagerie, The (1987)': {'TennesseeWilliams'},
#  'Glory (1989)': {'CivilWar'},
#  'Godfather, The (1972)': {'Mafia'},
#  'Godfather: Part II, The (1974)': {'AlPacino', 'Mafia'},
#  'Godfather: Part III, The (1990)': {'AlPacino',
#   'AndyGarcia',
#   'Classic',
#   'FrancisFordCoppola',
#   'mafia'},
#  'Godzilla (2014)': {'CreatureFeature'},
#  'Going Places (Valseuses, Les) (1974)': {'irreverent'},
#  'Gold Rush, The (1925)': {'mining'},
#  'Gone Baby Gone (2007)': {'CaseyAffleck', 'greatperformances', 'twist'},
#  'Gone Girl (2014)': {'Stupidending', 'annoying'},
#  'Gone with the Wind (1939)': {'CivilWar'},
#  'Good Copy Bad Copy (2007)': {'documentary', 'musicindustry', 'remixculture'},
#  'Good Earth, The (1937)': {'PearlSBuck'},
#  'Good Girl, The (2002)': {'adultery', 'youngermen'},
#  'Good Night, and Good Luck. (2005)': {'InNetflixqueue',
#   'McCarthyhearings',
#   'Morrow',
#   'journalism'},
#  'Good Will Hunting (1997)': {'heartwarming', 'inspirational'},
#  'Good Year, A (2006)': {'MarionCotillard'},
#  'Good bye, Lenin! (2003)': {'ColdWar'},
#  'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)': {'spaghettiwestern'},
#  'Goodfellas (1990)': {'Mafia'},
#  'Gospel According to St. Matthew, The (Vangelo secondo Matteo, Il) (1964)': {'Bible'},
#  'Graduate, The (1967)': {'SimonandGarfunkel'},
#  'Grand Day Out with Wallace and Gromit, A (1989)': {'moon'},
#  'Grand Illusion (La grande illusion) (1937)': {'downbeat', 'poignant'},
#  'Grapes of Wrath, The (1940)': {'depression', 'dustbowl'},
#  'Grave of the Fireflies (Hotaru no haka) (1988)': {'beautiful',
#   'downbeat',
#   'grim',
#   'mademecry',
#   'orphans',
#   'poignant',
#   'tearjerker',
#   'tragedy',
#   'tragic'},
#  'Gravity (2013)': {'Simple',
#   'clichecharacters',
#   'longshots',
#   'predictable',
#   'slowaction',
#   'visuallyappealing'},
#  'Grease (1978)': {'highschool'},
#  'Grease 2 (1982)': {'highschool'},
#  'Great Dictator, The (1940)': {'Nazis'},
#  'Great Escape, The (1963)': {'POW'},
#  'Great Expectations (1998)': {'CharlesDickens'},
#  'Great Santini, The (1979)': {'fatherhood'},
#  'Greatest Story Ever Told, The (1965)': {'Bible', 'religion'},
#  'Greed (1924)': {'gold'},
#  'Green Card (1990)': {'immigrants'},
#  'Green Lantern (2011)': {'CGI',
#   'DC',
#   'DCComics',
#   'RyanReynolds',
#   'audienceintelligenceunderestimated',
#   'cheesy',
#   'comicbook',
#   'space',
#   'superhero'},
#  'Green Mile, The (1999)': {'StephenKing'},
#  'Grey Zone, The (2001)': {'Holocaust'},
#  'Grifters, The (1990)': {'crime'},
#  'Grizzly Man (2005)': {'Animalmovie', 'bears'},
#  'Gross Anatomy (a.k.a. A Cut Above) (1989)': {'doctors'},
#  'Grosse Pointe Blank (1997)': {'hitmen', 'reunion'},
#  'Grown Ups 2 (2013)': {'AdamSandler'},
#  'Grumpier Old Men (1995)': {'moldy', 'old'},
#  'Guardians of the Galaxy (2014)': {'GreatVisuals',
#   'funny',
#   'humorous',
#   'unlikelyhero'},
#  'Guardians of the Galaxy 2 (2017)': {'fun'},
#  'Guerrilla: The Taking of Patty Hearst (2004)': {'Hearst'},
#  "Guess Who's Coming to Dinner (1967)": {'HepburnandTracy',
#   'interracialmarriage',
#   'prejudice',
#   'racism'},
#  'Guys and Dolls (1955)': {'Gambling'},
#  'Halloween II (1981)': {'halloween'},
#  'Halloween III: Season of the Witch (1982)': {'halloween'},
#  'Hamlet (1990)': {'Shakespeare'},
#  'Hamlet (1996)': {'Shakespeare'},
#  'Hancock (2008)': {'CharlizeTheron', 'WillSmith', 'badscript'},
#  'Hands Over the City (Le mani sulla città) (1963)': {'citypolitics',
#   'italy',
#   'politicalrightversusleft'},
#  'Hangover, The (2009)': {'LasVegas', 'casino', 'comedy', 'funny', 'hotel'},
#  'Hannah and Her Sisters (1986)': {'family'},
#  'Happy Gilmore (1996)': {'AdamSandler', 'golf', 'testtag'},
#  "Hard Day's Night, A (1964)": {'Beatles'},
#  'Hard-Boiled (Lat sau san taam) (1992)': {'gunfu', 'heroicbloodshed'},
#  'Harold and Maude (1971)': {'MayDecemberromance'},
#  'Harry Potter and the Chamber of Secrets (2002)': {'Magic', 'Wizards'},
#  'Harry Potter and the Goblet of Fire (2005)': {'Magic', 'Wizards'},
#  'Harry Potter and the Prisoner of Azkaban (2004)': {'Magic', 'Wizards'},
#  "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)": {'Everythingyouwantishere',
#   'Magic',
#   'Wizards',
#   'alanrickman',
#   'harrypotter',
#   'humorous'},
#  'Haunted World of El Superbeasto, The (2009)': {'Narrativepisstake'},
#  'Haunting, The (1963)': {'ghosts'},
#  'Haunting, The (1999)': {'remake'},
#  'He Loves Me... He Loves Me Not (À la folie... pas du tout) (2002)': {'obsession'},
#  'Hearts and Minds (1996)': {'InNetflixqueue', 'Vietnam'},
#  'Heathers (1989)': {'highschool'},
#  'Heaven (2002)': {'bombs'},
#  'Heavenly Creatures (1994)': {'Australia'},
#  'Hello Again (1987)': {'death'},
#  'Hello, Dolly! (1969)': {'matchmaker'},
#  'Henry V (1989)': {'Shakespeare'},
#  'Hero (Ying xiong) (2002)': {'martialarts'},
#  'High Fidelity (2000)': {'NickHornby', 'music'},
#  'High Noon (1952)': {'gunfight'},
#  'High and Low (Tengoku to jigoku) (1963)': {'InNetflixqueue'},
#  'Hilary and Jackie (1998)': {'InNetflixqueue'},
#  "Himalaya (Himalaya - l'enfance d'un chef) (1999)": {'InNetflixqueue'},
#  'Hiroshima Mon Amour (1959)': {'InNetflixqueue'},
#  'His Girl Friday (1940)': {'Screwball'},
#  'History of Future Folk, The (2012)': {'quirky'},
#  'History of Violence, A (2005)': {'InNetflixqueue'},
#  'Hobbit: An Unexpected Journey, The (2012)': {'Action', 'Myth'},
#  'Hobbit: The Desolation of Smaug, The (2013)': {'Tolkien',
#   'adventure',
#   'fantasy',
#   'toolong'},
#  'Holes (2003)': {'children'},
#  'Home Alone (1990)': {'christmas'},
#  'Home Alone 2: Lost in New York (1992)': {'MacaulayCulkin',
#   'family',
#   'funny',
#   'sequel'},
#  'Honey, I Shrunk the Kids (1989)': {'Disney'},
#  'Hook (1991)': {'PeterPan'},
#  'Hoop Dreams (1994)': {'basketball'},
#  'Hoosiers (a.k.a. Best Shot) (1986)': {'basketball'},
#  'Hope and Glory (1987)': {'InNetflixqueue'},
#  'Horse Feathers (1932)': {'Marxbrothers'},
#  'Hot Fuzz (2007)': {'britishcomedy'},
#  'Hotel Rwanda (2004)': {'genocide'},
#  'House of 1000 Corpses (2003)': {'RobZombie'},
#  'House of Flying Daggers (Shi mian mai fu) (2004)': {'martialarts'},
#  'House of Mirth, The (2000)': {'EdithWharton'},
#  'House of Sand and Fog (2003)': {'realestate'},
#  'Houseguest (1994)': {'Sinbad', 'bad'},
#  'How the Grinch Stole Christmas (a.k.a. The Grinch) (2000)': {'Dr.Seuss'},
#  'How to Make an American Quilt (1995)': {'wedding'},
#  'How to Steal a Million (1966)': {'InNetflixqueue'},
#  'Howards End (1992)': {'E.M.Forster'},
#  "Howl's Moving Castle (Hauru no ugoku shiro) (2004)": {'06OscarNominatedBestMovieAnimation',
#   'HayaoMiyazaki',
#   'InNetflixqueue',
#   'StudioGhibli',
#   'anime',
#   'fantasyworld'},
#  'Hudsucker Proxy, The (1994)': {'hulahoop'},
#  'Hulk (2003)': {'EricBana', 'dogs', 'madscientist', 'marvel'},
#  'Hunchback of Notre Dame, The (1939)': {'disability'},
#  'Hunt for Red October, The (1990)': {'TomClancy'},
#  'Hunting of the President, The (2004)': {'politics'},
#  'Hurricane, The (1999)': {'boxing'},
#  'Hurt Locker, The (2008)': {'war'},
#  'Hustle & Flow (2005)': {'hiphop'},
#  'Hustler, The (1961)': {'pool'},
#  'I Am Legend (2007)': {'Postapocalyptic',
#   'aloneintheworld',
#   'apocalypse',
#   'basedonabook',
#   'lastmanonearth',
#   'plotholes',
#   'postapocalyptic',
#   'religion',
#   'vampire'},
#  'I Capture the Castle (2003)': {'DodieSmith'},
#  'I Love You, Man (2009)': {'AndySamberg',
#   'JaimePressly',
#   'JasonSegel',
#   'PaulRudd',
#   'bromance',
#   'bromantic',
#   'comedy',
#   'masculinity'},
#  'I Remember Mama (1948)': {'motherhood'},
#  'I Was a Male War Bride (1949)': {'crossdressing', 'menindrag'},
#  "I'm Not Scared (Io non ho paura) (2003)": {'adolescence',
#   'crime',
#   'forkatie'},
#  'I.Q. (1994)': {'Einstein'},
#  'Ice Castles (1978)': {'figureskating'},
#  'Ice Storm, The (1997)': {'1970s'},
#  'Identity (2003)': {'JohnCusack'},
#  'Igby Goes Down (2002)': {'adolescence'},
#  'Ikiru (1952)': {'meditative',
#   'philosophical',
#   'poignant',
#   'purposefulness',
#   'terminalillness'},
#  'Illusionist, The (2006)': {'EdwardNorton',
#   'PaulGiamatti',
#   'costumedrama',
#   'magic'},
#  'Imitation of Life (1959)': {'motherhood', 'race'},
#  'Immortal Beloved (1994)': {'Beethoven'},
#  'Impostors, The (1998)': {'Screwball'},
#  'In America (2002)': {'immigrants'},
#  'In Bruges (2008)': {'ColinFarrell',
#   'RalphFiennes',
#   'blackcomedy',
#   'darkcomedy',
#   'drugs',
#   'friendship',
#   'irreverent',
#   'stylized'},
#  'In Cold Blood (1967)': {'Capote',
#   'blackandwhite',
#   'crime',
#   'deathpenalty',
#   'murder'},
#  'In Good Company (2004)': {'busniess'},
#  'In Her Shoes (2005)': {'sisters'},
#  'In Love and War (1996)': {'Hemingway'},
#  'In a Lonely Place (1950)': {'L.A.'},
#  'In the Bleak Midwinter (1995)': {'theater'},
#  'In the Heat of the Night (1967)': {'racism'},
#  'In the Line of Fire (1993)': {'assassination'},
#  'In the Mood For Love (Fa yeung nin wa) (2000)': {'Beautiful',
#   'Unique',
#   'atmospheric',
#   'bittersweet',
#   'dreamy',
#   'elegant',
#   'heartbreaking',
#   'intimate',
#   'loneliness',
#   'longing',
#   'longtakes',
#   'melancholic',
#   'melancholy',
#   'moody',
#   'nocturnal',
#   'romantic',
#   'visuallyappealing',
#   'visuallystunning'},
#  'In the Name of the Father (1993)': {'Ireland'},
#  'Inception (2010)': {'LeonardoDiCaprio',
#   'action',
#   'alternatereality',
#   'bigbudget',
#   'cerebral',
#   'clever',
#   'complicated',
#   'deadwife',
#   'dreamlike',
#   'greatsoundtrack',
#   'heist',
#   'intellectual',
#   'mindfuck',
#   'philosophy',
#   'psychological',
#   'psychology',
#   'scifi',
#   'surreal',
#   'suspense',
#   'thoughtprovoking',
#   'visuallyappealing'},
#  'Incredibles, The (2004)': {'Disney',
#   'SamuelL.Jackson',
#   'animation',
#   'superhero'},
#  'Independence Day (a.k.a. ID4) (1996)': {'aliens'},
#  'Indiana Jones and the Last Crusade (1989)': {'HolyGrail', 'archaeology'},
#  'Indiana Jones and the Temple of Doom (1984)': {'archaeology'},
#  'Indochine (1992)': {'Vietnam'},
#  'Infernal Affairs (Mou gaan dou) (2002)': {'police'},
#  'Inglourious Basterds (2009)': {'BradPitt',
#   'ChristophWaltz',
#   'QuentinTarantino',
#   'blackcomedy',
#   'satire'},
#  'Inherit the Wind (1960)': {'court', 'evolution', 'religion'},
#  'Inside Job (2010)': {'business',
#   'corruption',
#   'economics',
#   'investorcorruption',
#   'politics',
#   'truth'},
#  'Inside Llewyn Davis (2013)': {'atmospheric',
#   'cinematography',
#   'depressing',
#   'funny'},
#  'Insider, The (1999)': {'tobacco', 'truestory'},
#  'Insomnia (2002)': {'AlPacino',
#   'HilarySwank',
#   'RobinWilliams',
#   'atmospheric',
#   'insomnia',
#   'thoughtprovoking'},
#  'Interstellar (2014)': {'ChristopherNolan',
#   'baddialogue',
#   'blackhole',
#   'philosophicalissues',
#   'scifi',
#   'thoughtprovoking',
#   'timetravel',
#   'visuallyappealing'},
#  'Into the Woods (1991)': {'InNetflixqueue', 'fairytales'},
#  'Intouchables (2011)': {'emotional', 'sexuality'},
#  'Invasion of the Body Snatchers (1956)': {'1950s'},
#  'Invincible Iron Man, The (2007)': {'animation'},
#  'Invisible Man, The (1933)': {'invisibility'},
#  'Invisible, The (2007)': {'HORRIBLEACTING', 'interesting'},
#  'Iron Giant, The (1999)': {'animation', 'robots'},
#  'Irreversible (Irréversible) (2002)': {'dark', 'disturbing'},
#  'It Comes at Night (2017)': {'Suspenseful', 'paranoia'},
#  'It Could Happen to You (1994)': {'gambling'},
#  'It Happened One Night (1934)': {'Screwball'},
#  'It Takes Two (1995)': {'twins'},
#  "It's Such a Beautiful Day (2012)": {'moving',
#   'philosopical',
#   'surreal',
#   'weird'},
#  "It's a Wonderful Life (1946)": {'Christmas'},
#  'Italian Job, The (2003)': {'heist'},
#  'JFK (1991)': {'politics', 'president'},
#  'Jack and Sarah (1995)': {'babies'},
#  'Jane Eyre (1970)': {'CharlotteBronte'},
#  'Jarhead (2005)': {'JakeGyllenhaal', 'Modernwar'},
#  'Jaws (1975)': {'Shark'},
#  'Jaws 3-D (1983)': {'shark'},
#  'Jerry Maguire (1996)': {'sports'},
#  'Jesus of Montreal (Jésus de Montréal) (1989)': {'reciprocalspectator'},
#  'Jetée, La (1962)': {'postapocalyptic'},
#  'Jezebel (1938)': {'BetteDavis', 'Oscar(BestActress)'},
#  'John Wick (2014)': {'KeanuReeves',
#   'Revenge',
#   'action',
#   'darkhero',
#   'gunfu',
#   'killer',
#   'secretsociety',
#   'stylish',
#   'widows/widowers'},
#  'John Wick: Chapter Two (2017)': {'HeroicBloodshed',
#   'KeanuReeves',
#   'action',
#   'darkhero',
#   'guntactics',
#   'hitman',
#   'organizedcrime',
#   'secretsociety'},
#  'Johnny Belinda (1948)': {'deafness'},
#  'Jonah: A VeggieTales Movie (2002)': {'Bible'},
#  'Jumanji (1995)': {'RobinWilliams', 'fantasy', 'game', 'magicboardgame'},
#  'Jumanji: Welcome to the Jungle (2017)': {'Action',
#   'Comedy',
#   'DwayneJohnson',
#   'funny'},
#  'Junebug (2005)': {'pregnancy'},
#  'Jungle Book, The (1967)': {'Disney'},
#  'Jungle2Jungle (a.k.a. Jungle 2 Jungle) (1997)': {'jungle'},
#  'Juno (2007)': {'MichaelCera',
#   'notablesoundtrack',
#   'pregnancy',
#   'teenagepregnancy',
#   'witty'},
#  'Jurassic Park (1993)': {'Dinosaur'},
#  'Jurassic Park III (2001)': {'dinosaurs'},
#  'Just Cause (1995)': {'court'},
#  'Just Eat It: A Food Waste Story (2014)': {'Sustainability',
#   'dumpsterdiving'},
#  'K-PAX (2001)': {'aliens', 'psychiatrist'},
#  'Karate Kid, Part II, The (1986)': {'martialarts'},
#  'Karate Kid, Part III, The (1989)': {'martialarts'},
#  'Karate Kid, The (1984)': {'martialarts'},
#  'Keeping the Faith (2000)': {'priest', 'rabbi'},
#  'Kid Stays in the Picture, The (2002)': {'moviebusiness'},
#  'Kid, The (1921)': {'orphans'},
#  'Kids (1995)': {'NewYorkCity', 'Nudity(FullFrontal)', 'controversial'},
#  "Kiki's Delivery Service (Majo no takkyûbin) (1989)": {'anime'},
#  'Kill Bill: Vol. 1 (2003)': {'martialarts', 'revenge'},
#  'Kill Bill: Vol. 2 (2004)': {'revenge'},
#  'Killing Fields, The (1984)': {'Cambodia', 'Vietnam'},
#  'Killing, The (1956)': {'heist'},
#  'Kind Hearts and Coronets (1949)': {'family', 'multipleroles', 'murder'},
#  'King Kong (2005)': {'bigbudget'},
#  'King and I, The (1956)': {'Siam'},
#  'Kingdom of Heaven (2005)': {'DavidThewlis',
#   'EvaGreen',
#   'LiamNeeson',
#   'OrlandoBloom'},
#  'Kingsman: The Secret Service (2015)': {'slick'},
#  'Kiss Kiss Bang Bang (2005)': {'InNetflixqueue',
#   'RobertDowneyJr.',
#   'blackcomedy',
#   'clever',
#   'fastpaceddialogue',
#   'gooddialogue',
#   'witty'},
# ...
#  'Lady in the Water (2006)': {'M.NightShyamalan',
#   'PaulGiamatti',
#   'bad',
#   'disappointing',
#   'faerietale',
#   'fairytale',
#   'farfetched'},
#  'Lagaan: Once Upon a Time in India (2001)': {'India'},
#  'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)': {'anime'},
#  'Lara Croft Tomb Raider: The Cradle of Life (2003)': {'AngelinaJolie',
#   'adventure',
#   'heroineintightsuit'},
#  'Last Days of Disco, The (1998)': {'NoDVDatNetflix'},
#  'Last Days, The (1998)': {'Holocaust', 'Hungary'},
#  'Last Emperor, The (1987)': {'China'},
#  'Last Picture Show, The (1971)': {'blackandwhite'},
#  'Last Temptation of Christ, The (1988)': {'Bible', 'Katzanzakis'},
#  'Last of the Mohicans, The (1992)': {'Hawkeye', 'JamesFennimoreCooper'},
#  'Lavender Hill Mob, The (1951)': {'crime', 'heist'},
#  'Lawrence of Arabia (1962)': {'MiddleEast'},
#  'Layer Cake (2004)': {'Britishgangster',
#   'Exquisiteplotting.',
#   'TomHardy',
#   'confusing',
#   'danielcraig',
#   'organizedcrime',
#   'stylish'},
#  'League of Extraordinary Gentlemen, The (a.k.a. LXG) (2003)': {'PetaWilson',
#   'SeanConnery',
#   'captainnemo',
#   'comicbook',
#   'gothic',
#   'superhero'},
#  'Leaving Las Vegas (1995)': {'alcoholism'},
#  'Legal Eagles (1986)': {'lawyers'},
#  'Legally Blonde (2001)': {'lawyers'},
#  'Legally Blonde 2: Red, White & Blonde (2003)': {'politics'},
#  "Lemony Snicket's A Series of Unfortunate Events (2004)": {'JimCarrey',
#   'darkcomedy',
#   'merylstreep',
#   'quirky',
#   'stylized'},
#  'Letter to Three Wives, A (1949)': {'InNetflixqueue'},
#  'Letter, The (1940)': {'InNetflixqueue'},
#  'Liar Liar (1997)': {'lawyer'},
#  'Life Aquatic with Steve Zissou, The (2004)': {'heartwarming',
#   'offbeatcomedy',
#   'quirky',
#   'trippy',
#   'visuallyappealing',
#   'whimsical'},
#  'Life Is Beautiful (La Vita è bella) (1997)': {'Heartwarming',
#   'Holocaust',
#   'bittersweet',
#   'emotional',
#   'poignant',
#   'sentimental',
#   'tearjerker',
#   'tearjerking'},
#  'Life of Pi (2012)': {'India', 'cinematography', 'surreal'},
#  'Lifeboat (1944)': {'survival'},
#  'Lilya 4-Ever (Lilja 4-ever) (2002)': {'Depressing',
#   'melancholy',
#   'prostitution',
#   'sad'},
#  'Limelight (1952)': {'InNetflixqueue'},
#  'Lion King, The (1994)': {'Disney',
#   'Disneyanimatedfeature',
#   'Oscar(BestMusicOriginalScore)',
#   'soundtrack'},
#  'Little Foxes, The (1941)': {'family'},
#  'Little Man Tate (1991)': {'prodigies'},
#  'Little Princess, A (1995)': {'England', 'GirlPower', 'India'},
#  'Little Voice (1998)': {'InNetflixqueue'},
#  'Little Women (1994)': {'LouisaMayAlcott'},
#  'Logan (2017)': {'dark',
#   'emotional',
#   'gritty',
#   'heartbreaking',
#   'predictibleplot'},
#  'Lone Star (1996)': {'InNetflixqueue'},
#  "Long Night's Journey Into Day (2000)": {"EugeneO'Neill"},
#  'Long, Hot Summer, The (1958)': {'InNetflixqueue'},
#  "Look Who's Talking (1989)": {'babies'},
#  'Looking for Comedy in the Muslim World (2005)': {'InNetflixqueue'},
#  'Lord of War (2005)': {'wapendrama'},
#  'Lord of the Flies (1963)': {'island'},
#  'Lord of the Rings, The (1978)': {'Tolkein', 'classic'},
#  'Lord of the Rings: The Fellowship of the Ring, The (2001)': {'Magic',
#   'Tolkein',
#   'fantasy',
#   'highfantasy',
#   'mythology',
#   'tolkien',
#   'wizards'},
#  'Lord of the Rings: The Return of the King, The (2003)': {'Adventure',
#   'Tolkein',
#   'Tolkien',
#   'ensemblecast',
#   'fantasy',
#   'fantasyworld',
#   'greatsoundtrack',
#   'lordoftherings',
#   'scenic',
#   'stylized'},
#  'Lord of the Rings: The Two Towers, The (2002)': {'Myth', 'Tolkein'},
#  "Losin' It (1983)": {'virginity'},
#  'Lost Horizon (1937)': {'ShangriLa'},
#  'Lost Weekend, The (1945)': {'alcoholism'},
#  'Lost World: Jurassic Park, The (1997)': {'dinosaurs'},
#  'Lost in Translation (2003)': {'Japan', 'atmospheric'},
#  'Love Bug, The (1969)': {'Disney', 'race'},
#  'Love Liza (2002)': {'drugs', 'planes', 'widows/widowers'},
#  "Love Me If You Dare (Jeux d'enfants) (2003)": {'cruelcharacters'},
#  'Love Story (1970)': {'death'},
#  'Lovely & Amazing (2001)': {'sisterhood', 'women'},
#  'Lucky Number Slevin (2006)': {'twistending'},
#  'Lust for Life (1956)': {'VanGogh'},
#  'Luther (2003)': {'religion'},
#  'Luzhin Defence, The (2000)': {'Nabokov'},
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)': {'Action',
#   'French',
#   'GaryOldman',
#   'Guns',
#   'JeanReno',
#   'Lolitatheme',
#   'LucBesson',
#   'NataliePortman',
#   'assassin',
#   'assassination',
#   'assassins',
#   'awkwardromance',
#   'corruption',
#   'crime',
#   'disturbing',
#   'drama',
#   'friendship',
#   'greatacting',
#   'hitman',
#   'hitmen',
#   'humorous',
#   'imdbtop250',
#   'loneliness',
#   'lovestory',
#   'organizedcrime',
#   'police',
#   'policecorruption',
#   'quirky',
#   'sniper',
#   'tense',
#   'touching',
#   'unique'},
#  'M (1931)': {'atmospheric',
#   'chilly',
#   'creepy',
#   'menacing',
#   'mentalillness',
#   'oninous',
#   'serialkiller'},
#  'M. Butterfly (1993)': {'Japan', 'sexuality'},
#  'Macbeth (a.k.a. Tragedy of Macbeth, The) (1971)': {'InNetflixqueue',
#   'Shakespeare'},
#  'Mad Max: Fury Road (2015)': {'beautiful',
#   'cinematography',
#   'visuallyappealing'},
#  'Madness of King George, The (1994)': {'England', 'mentalillness'},
#  'Magdalene Sisters, The (2002)': {'religion'},
#  'Magnolia (1999)': {'L.A.'},
#  'Major League (1989)': {'baseball'},
#  'Make Way for Tomorrow (1937)': {'heartbreaking'},
#  'Maltese Falcon, The (1941)': {'statue'},
#  'Maltese Falcon, The (a.k.a. Dangerous Female) (1931)': {'heist'},
#  "Man Bites Dog (C'est arrivé près de chez vous) (1992)": {'blackcomedy',
#   'crazy',
#   'dark',
#   'darkcomedy',
#   'darkhumor',
#   'serialkiller'},
#  "Man Who Wasn't There, The (2001)": {'CoenBrothers'},
#  'Man Who Would Be King, The (1975)': {'India'},
#  'Man Without a Past, The (Mies vailla menneisyyttä) (2002)': {'amnesia'},
#  'Man in the Iron Mask, The (1998)': {'seenmorethanonce'},
#  'Man of Steel (2013)': {'AmyAdams', 'superhero'},
#  'Man on the Moon (1999)': {'AndyKaufman'},
#  "Man on the Train (Homme du train, L') (2002)": {'trains'},
#  'Manchurian Candidate, The (1962)': {'assassination', 'brainwashing'},
#  'Manhattan (1979)': {'blackandwhite'},
#  'Manhunter (1986)': {'HannibalLecter', 'serialkiller'},
#  'Marat/Sade (1966)': {'reciprocalspectator'},
#  'Margin Call (2011)': {'KevinSpacey',
#   'WallStreet',
#   'bank',
#   'bigcorporations',
#   'business',
#   'corruption',
#   'financialcrisis',
#   'realistic',
#   'suspense'},
#  'Maria Full of Grace (Maria, Llena eres de gracia) (2004)': {'drugs',
#   'immigrants'},
#  'Marie Antoinette (2006)': {'cinematography', 'lyrical'},
#  'Mark of Zorro, The (1940)': {'swashbuckler'},
#  'Married to the Mob (1988)': {'Mafia'},
#  'Mary Poppins (1964)': {'Disney', 'nanny'},
#  'Mary Reilly (1996)': {'JekyllandHyde'},
#  "Mary Shelley's Frankenstein (Frankenstein) (1994)": {'gothic'},
#  'Mary and Max (2009)': {'bittersweet',
#   'blackcomedy',
#   'characterstudy',
#   'darkcomedy',
#   'friendship',
#   'loneliness',
#   'mentalillness',
#   'philosophical',
#   'poignant',
#   'quirky',
#   'sad',
#   'sweet',
#   'touching'},
#  'Mask (1985)': {'disability'},
#  'Mask of Zorro, The (1998)': {'California', 'Mexico'},
#  'Match Factory Girl, The (Tulitikkutehtaan tyttö) (1990)': {'depression'},
#  'Matchstick Men (2003)': {'conmen', 'fatherhood'},
#  'Matrix, The (1999)': {'alternateuniverse',
#   'martialarts',
#   'philosophy',
#   'postapocalyptic',
#   'scifi'},
#  'May (2002)': {'doll'},
#  'Maze Runner, The (2014)': {'action',
#   'dystopia',
#   'plotholes',
#   'postapocalyptic',
#   'survival',
#   'thriller',
#   'unexplained',
#   'weakplot'},
#  'Me Myself I (2000)': {'alternateendings'},
#  'Mean Creek (2004)': {'revenge'},
#  'Mean Girls (2004)': {'HighSchool', 'clever', 'lesbiansubtext'},
#  'Meatballs (1979)': {'camp'},
#  'Meet Dave (2008)': {'enjoyable'},
#  'Meet John Doe (1941)': {'journalism'},
#  'Meet Me in St. Louis (1944)': {'1900s'},
#  'Meet the Fockers (2004)': {'BenStiller', 'RobertDeNiro'},
#  'Meet the Parents (2000)': {'RobertDeNiro', 'comedy'},
#  'Meet the Robinsons (2007)': {'Somethingforeveryoneinthisone...sawitwithoutandplanonseeingitwithkids!'},
#  'Memento (2000)': {'Backwards.memory',
#   'Mindfuck',
#   'cerebral',
#   'dark',
#   'dreamlike',
#   'mystery',
#   'nonlinear',
#   'psychological',
#   'psychology',
#   'twistending'},
#  'Men in Black (a.k.a. MIB) (1997)': {'aliens'},
#  'Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (2002)': {'crappysequel',
#   'firstwasmuchbetter',
#   'sequel'},
#  'Merchant of Venice, The (2004)': {'Shakespeare'},
#  'Michael Collins (1996)': {'Ireland'},
#  'Midnight Clear, A (1992)': {'InNetflixqueue'},
#  'Midnight Cowboy (1969)': {'prostitution'},
#  'Midnight Express (1978)': {'InNetflixqueue'},
#  'Midnight in the Garden of Good and Evil (1997)': {'Savannah'},
#  'Mighty Aphrodite (1995)': {'adoption', 'prostitution'},
#  'Mighty Wind, A (2003)': {'mockumentary'},
#  'Mighty, The (1998)': {'adolescence'},
#  'Mildred Pierce (1945)': {'motherhood'},
#  'Millennium Actress (Sennen joyû) (2001)': {'InNetflixqueue'},
#  "Miller's Crossing (1990)": {'Mafia'},
#  'Million Dollar Baby (2004)': {'boxing'},
#  'Millions (2004)': {'religion', 'saints'},
#  'Minority Report (2002)': {'future'},
#  'Miracle Worker, The (1962)': {'blindness', 'deaf'},
#  'Miracle on 34th Street (1994)': {'Christmas'},
#  'Mirror Has Two Faces, The (1996)': {'personalsads'},
#  'Misery (1990)': {'claustrophobic',
#   'horror',
#   'scary',
#   'stephenking',
#   'suspenseful',
#   'tense',
#   'thriller'},
#  'Miss Congeniality (2000)': {'pageant'},
#  'Missing (1982)': {'Chile', 'SouthAmerica', 'politics'},
#  'Mission, The (1986)': {'Missionary', 'Priest'},
#  'Mission: Impossible (1996)': {'basedonaTVshow'},
#  'Mississippi Burning (1988)': {'race', 'rasicm'},
#  'Mississippi Masala (1991)': {'InNetflixqueue'},
#  'Modern Times (1936)': {'factory'},
#  'Monsoon Wedding (2001)': {'India'},
#  'Monster (2003)': {'serialkiller'},
#  "Monster's Ball (2001)": {'race'},
#  'Monty Python Live at the Hollywood Bowl (1982)': {'spoof'},
#  'Monty Python and the Holy Grail (1975)': {'England',
#   'KingArthur',
#   'MontyPython',
#   'britishcomedy'},
#  "Monty Python's Life of Brian (1979)": {'Bible', 'parody', 'religion'},
#  "Monty Python's The Meaning of Life (1983)": {'britishcomedy'},
#  'Moon (2009)': {'2001like', 'Scifi', 'solitude'},
#  'Moonrise Kingdom (2012)': {'quirky'},
#  'Moonstruck (1987)': {'NewYork'},
#  'More (1998)': {'claymation',
#   'creativity',
#   'dystopia',
#   'freetodownload',
#   'imagination',
#   'nodialogue',
#   'socialcommentary'},
#  'Mother! (2017)': {'allegorical', 'uncomfortable', 'unsettling'},
#  'Movie 43 (2013)': {'Rlanguage',
#   'embarassingscenes',
#   'offensive',
#   'sarcasm',
#   'satire'},
#  "Mr. Holland's Opus (1995)": {'music'},
#  'Mr. Smith Goes to Washington (1939)': {'Politics'},
#  'Mrs. Brown (a.k.a. Her Majesty, Mrs. Brown) (1997)': {'England',
#   'QueenVictoria'},
#  'Mrs. Doubtfire (1993)': {'crossdressing', 'divorce', 'menindrag'},
#  'Much Ado About Nothing (1993)': {'Shakespeare'},
#  'Mulholland Falls (1996)': {'bad'},
#  'Munich (2005)': {'InNetflixqueue'},
#  'Muppet Treasure Island (1996)': {'muppets'},
#  'Murder in the First (1995)': {'prison'},
#  'Murder on a Sunday Morning (Un coupable idéal) (2001)': {'crime',
#   'documentary'},
#  'Murder on the Orient Express (1974)': {'AgathaChristie',
#   'Oscar(BestSupportingActress)',
#   'train'},
#  "Muriel's Wedding (1994)": {'Australia', 'weddings'},
#  'Music Box (1989)': {'Nazis'},
#  'Mutiny on the Bounty (1935)': {'ships'},
#  "My Best Friend's Wedding (1997)": {'romanticcomedy', 'wedding', 'weddings'},
#  'My Blue Heaven (1990)': {'Mafia'},
#  'My Cousin Vinny (1992)': {'court'},
#  'My Demon Lover (1987)': {'demons'},
#  'My Fair Lady (1964)': {'GeorgeBernardShaw'},
#  'My Family (1995)': {'InNetflixqueue'},
#  'My Favorite Year (1982)': {'television'},
#  'My Flesh and Blood (2003)': {'InNetflixqueue'},
#  'My Left Foot (1989)': {'InNetflixqueue'},
#  'My Life (1993)': {'death'},
#  'My Life Without Me (2003)': {'adultery', 'terminalillness'},
#  'My Man Godfrey (1936)': {'butler', 'homeless', 'screwball'},
#  'My Neighbor Totoro (Tonari no Totoro) (1988)': {'anime'},
#  'My Stepmother Is an Alien (1988)': {'aliens'},
#  'Mystery Men (1999)': {'superhero'},
#  'Mystery Science Theater 3000: The Movie (1996)': {'spoof'},
#  'Mystic River (2003)': {'childabuse', 'kidnapping'},
#  'Name of the Rose, The (Name der Rose, Der) (1986)': {'religion'},
#  'Napoleon Dynamite (2004)': {'highschool'},
#  'National Velvet (1944)': {'horses'},
#  'Natural Born Killers (1994)': {'brutality',
#   'controversial',
#   'darkcomedy',
#   'psychedelic',
#   'satire',
#   'stylized'},
#  'Natural, The (1984)': {'baseball', 'sports'},
#  'Necessary Roughness (1991)': {'football'},
#  'Negotiator, The (1998)': {'police'},
#  'Nell (1994)': {'disability', 'twins'},
#  'Neon Genesis Evangelion: Death & Rebirth (Shin seiki Evangelion Gekijô-ban: Shito shinsei) (1997)': {'Recap'},
#  'Neon Genesis Evangelion: The End of Evangelion (Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni) (1997)': {'anime',
#   'endoftheworld',
#   'epic',
#   'mecha',
#   'psychology'},
#  'Net, The (1995)': {'computers'},
#  'Network (1976)': {'journalism'},
#  'Never Been Kissed (1999)': {'highschool'},
#  'Next Stop Wonderland (1998)': {'Boston', 'aquarium', 'personalsads'},
#  'Nicholas Nickleby (2002)': {'Dickens'},
#  'Night and Day (1946)': {'ColePorter'},
#  'Night at the Museum (2006)': {'BenStiller', 'RobinWilliams'},
#  'Night at the Opera, A (1935)': {'Marxbrothers', 'opera'},
#  'Night at the Roxbury, A (1998)': {'SNL'},
#  'Night of the Hunter, The (1955)': {'goodandevil'},
#  'Night of the Living Dead (1968)': {'zombies'},
#  'Night of the Shooting Stars (Notte di San Lorenzo, La) (1982)': {'WorldWarII'},
#  'Nightmare Before Christmas, The (1993)': {'Christmas', 'Halloween'},
#  'Nights of Cabiria (Notti di Cabiria, Le) (1957)': {'InNetflixqueue'},
#  'Ninotchka (1939)': {'ColdWar', 'Russia'},
#  'Nixon (1995)': {'politics', 'president'},
#  'Nobody Knows (Dare mo shiranai) (2004)': {'orphans'},
#  'Norma Rae (1979)': {'Union'},
#  'North Country (2005)': {'InNetflixqueue', 'courtroomdrama'},
#  'North by Northwest (1959)': {'AlfredHitchcock',
#   'MountRushmore',
#   'imdbtop250'},
#  'Northfork (2003)': {'flood'},
#  'Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)': {'vampires'},
#  'Notebook, The (2004)': {'memoryloss', 'romance', 'sad'},
#  'Notorious (1946)': {'assassination'},
#  'Now You See Me (2013)': {'illusions',
#   'overcomplicated',
#   'predictable',
#   'stupidending'},
#  'Now, Voyager (1942)': {'psychology'},
#  'Nowhere in Africa (Nirgendwo in Afrika) (2001)': {'WorldWarII'},
#  'O Brother, Where Art Thou? (2000)': {'bluegrass'},
#  'Observe and Report (2009)': {'SethRogen'},
#  "Ocean's Eleven (2001)": {'heist'},
#  'Odd Couple, The (1968)': {'InNetflixqueue'},
#  'Office Space (1999)': {'stapler', 'workplace'},
#  'Official Story, The (La historia oficial) (1985)': {'missingchildren'},
#  'Oh, God! Book II (1980)': {'religion'},
#  'Oklahoma! (1955)': {'RogersandHammerstein'},
#  'Old Boy (2003)': {'bizarre',
#   'claustrophobic',
#   'depressing',
#   'disturbing',
#   'hallucinatory',
#   'paranoid',
#   'surreal',
#   'twisted'},
#  'Old School (2003)': {'WillFerrell', 'comedy'},
#  'Oliver Twist (1948)': {'Dickens'},
#  'Oliver Twist (2005)': {'Dickens'},
#  'Oliver! (1968)': {'Dickens'},
#  'Omen, The (1976)': {'demons'},
#  'On Golden Pond (1981)': {'aging'},
#  'On the Waterfront (1954)': {'boxing', 'couldabeenacontender'},
#  'Once Bitten (1985)': {'vampire'},
#  "Once Upon a Time in the West (C'era una volta il West) (1968)": {'spaghettiwestern'},
#  'Once Were Warriors (1994)': {'InNetflixqueue'},
#  "One Flew Over the Cuckoo's Nest (1975)": {'emotional',
#   'jacknicholson',
#   'mentalillness'},
#  'One Hour Photo (2002)': {'photography', 'psychopaths'},
#  'One, Two, Three (1961)': {'Japan'},
#  'Ordet (Word, The) (1955)': {'religion'},
#  'Oscar and Lucinda (a.k.a. Oscar & Lucinda) (1997)': {'gambling'},
#  'Othello (1995)': {'Shakespeare'},
#  'Other Sister, The (1999)': {'disability'},
#  'Our Hospitality (1923)': {'InNetflixqueue'},
#  'Out of Africa (1985)': {'Africa', 'adultery'},
#  'Out of Sight (1998)': {'heist'},
#  'Out of the Past (1947)': {'memory'},
#  'Outsiders, The (1983)': {'S.E.Hinton'},
#  'Owning Mahowny (2003)': {'gambling'},
#  'Ox-Bow Incident, The (1943)': {'InNetflixqueue'},
#  'Paddington (2014)': {'heartwarming'},
#  ...}

# %%
movies_df = movies_df.merge(ratings, on = 'movieId')
movies_df.drop(['userId', 'timestamp'], axis = 1, inplace=True)
#movies_df = movies_df.merge(ratings)
movies_df
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres        tag  rating
# 0       Adventure Animation Children Comedy Fantasy      pixar     4.0
# 1       Adventure Animation Children Comedy Fantasy      pixar     4.0
# 2       Adventure Animation Children Comedy Fantasy      pixar     4.5
# 3       Adventure Animation Children Comedy Fantasy      pixar     2.5
# 4       Adventure Animation Children Comedy Fantasy      pixar     4.5
# ...                                             ...        ...     ...
# 233208              Action Adventure Children SciFi  star wars     5.0
# 233209                Action Animation Comedy SciFi      anime     3.5
# 233210                Action Animation Comedy SciFi     comedy     3.5
# 233211                Action Animation Comedy SciFi    gintama     3.5
# 233212                Action Animation Comedy SciFi   remaster     3.5
#
# [233213 rows x 5 columns]

# %%
movies.shape
# Out:
# (9742, 3)

# %%
movies_df.shape
# Out:
# (233213, 5)

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-', '').split('|'))

# %%
movies['genres'] = [change_string(g) for g in movies.genres.values]

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(movies['genres'])

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
