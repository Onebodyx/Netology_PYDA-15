# %%
import pandas as pd
import numpy as np
import seaborn as sns
 
from matplotlib import pyplot as plt
 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('final_data.csv', delimiter=';')
data.head(5)
# Out:
#    Unnamed: 0                             address                  z_address  \
# 0           2  Address: 1160 Mission Street #2007  1160 Mission St UNIT 2007
# 1           5       Address: 260 King Street #475       260 King St UNIT 475
# 2           7     Address: 560 Missouri Street #B        560 Missouri St # B
# 3           9        Address: 350 Missouri Street            350 Missouri St
# 4          11         Address: 3658 Folsom Street             3658 Folsom St
#
#    bathrooms  bedrooms  finishedsqft lastsolddate  lastsoldprice   latitude  \
# 0        2.0       2.0        1043.0   02/17/2016      1300000.0  37.778705
# 1        1.0       1.0         903.0   02/17/2016       750000.0  37.777641
# 2        4.0       3.0        1425.0   02/17/2016      1495000.0  37.759198
# 3        3.0       3.0        2231.0   02/17/2016      2700000.0  37.761886
# 4        3.0       3.0        1300.0   02/17/2016      1530000.0  37.740795
#
#     longitude     neighborhood  totalrooms       usecode  yearbuilt  \
# 0 -122.412635  South of Market         4.0   Condominium     2007.0
# 1 -122.393417  South of Market         3.0   Condominium     2004.0
# 2 -122.396516     Potrero Hill         6.0   Condominium     2003.0
# 3 -122.396769     Potrero Hill        10.0  SingleFamily     1927.0
# 4 -122.413453   Bernal Heights         4.0  SingleFamily     1900.0
#
#    zestimate zindexvalue  zipcode        zpid
# 0  1167508.0     975,700  94103.0  83152781.0
# 1   823719.0     975,700  94107.0  69819817.0
# 2  1708594.0   1,277,600  94107.0  64972847.0
# 3  2411236.0   1,277,600  94107.0  15149489.0
# 4  1918539.0   1,248,000  94110.0  15161978.0

# %%
data.shape
# Out:
# (11330, 18)

# %% [markdown]
# Будем использовать линейную регрессию для тестирования качества данных

# %%
def get_score(X,y, random_seed=42, model=None):
  if model is None:
    model = LinearRegression()
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_seed )  
  model.fit(X_train, y_train)
  return model.score(X_test, y_test)

# %% [markdown]
# Для поиска выбросов будем использовать boxplot

# %%
def get_boxplot(X, columns=[]):
    for i in columns:
        sns.boxplot(x=X[i])
    pass  

def get_pairplot(X, columns=None):
    if columns is None:
        columns = list(X.columns)
    sns.pairplot(X[columns])
    pass

# %% [markdown]
# Для заполнения пропущенных значений будем использовать стандартные способы
# - заполнение значением
# - max
# - min
# - mode
# - median
# - mean
# - метод индикатора
# - линейная регрессия

# %%
def get_value(X, column, mode='mean', value=0, columns_for_reg=None):
  if mode == 'value':
    X.loc[X[X[column].isna()].index ,column] = value
  elif mode == 'max':
    X.loc[X[X[column].isna()].index ,column] = X[column].max()
  elif mode == 'min':
    X.loc[X[X[column].isna()].index ,column] = X[column].min()
  elif mode == 'median':
    X.loc[X[X[column].isna()].index ,column] = X[column].median()    
  elif mode == 'mode':
    X.loc[X[X[column].isna()].index, column] = X[column].mode()[0]  
  elif mode == 'indicator':
    X.loc[X[X[column].isna()].index, column] = 0
    X['ind_'+str(column)] = 0
    X.loc[X[X[column].isna()].index, 'ind_'+str(column)] = 1
  elif mode == 'linreg':
    if columns_for_reg is None:
      cols = list(X.select_dtypes([np.number]).columns) 
      cols.remove(column)
    else:
      cols = columns_for_reg
    X_tmp = X.dropna()  
    m = LinearRegression().fit(X_tmp[cols], X_tmp[column])
    X.loc[X[X[column].isna()].index, column] = m.predict(X[X[column].isna()][cols])
  else:
    X.loc[X[X[column].isna()].index, column] = X[column].mean()
  return X

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11330 entries, 0 to 11329
# Data columns (total 18 columns):
# Unnamed: 0       11330 non-null int64
# address          11330 non-null object
# z_address        11330 non-null object
# bathrooms        11330 non-null float64
# bedrooms         11330 non-null float64
# finishedsqft     11211 non-null float64
# lastsolddate     11330 non-null object
# lastsoldprice    11330 non-null float64
# latitude         11315 non-null float64
# longitude        11315 non-null float64
# neighborhood     11330 non-null object
# totalrooms       11281 non-null float64
# usecode          11290 non-null object
# yearbuilt        11330 non-null float64
# zestimate        11330 non-null float64
# zindexvalue      11330 non-null object
# zipcode          11330 non-null float64
# zpid             11330 non-null float64
# dtypes: float64(11), int64(1), object(6)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0     bathrooms      bedrooms  finishedsqft  lastsoldprice  \
# count  11330.000000  11330.000000  11330.000000  11211.000000   1.133000e+04
# mean    9171.729214      1.980229      2.614475   1586.081349   1.263928e+06
# std     4921.941074      1.047358      1.299457    922.815803   1.042079e+06
# min        2.000000      0.500000      0.000000      1.000000   5.350000e+02
# 25%     5039.750000      1.000000      2.000000   1019.000000   7.292500e+05
# 50%     9198.500000      2.000000      2.000000   1362.000000   9.900000e+05
# 75%    13374.750000      2.000000      3.000000   1878.000000   1.450000e+06
# max    17632.000000     14.000000     20.000000  27275.000000   2.388900e+07
#
#            latitude     longitude    totalrooms     yearbuilt     zestimate  \
# count  11315.000000  11315.000000  11281.000000  11330.000000  1.133000e+04
# mean      37.759715   -122.436508      6.113997   1948.498147  1.565695e+06
# std        0.025583      0.030742     12.151195     37.911196  1.229417e+06
# min       37.708170   -122.510726      1.000000   1860.000000  4.323850e+05
# 25%       37.739284   -122.455149      4.000000   1916.000000  9.052375e+05
# 50%       37.760514   -122.432510      5.000000   1940.000000  1.230758e+06
# 75%       37.781386   -122.413353      7.000000   1986.000000  1.731170e+06
# max       37.806083   -122.381201   1264.000000   2016.000000  1.553325e+07
#
#             zipcode          zpid
# count  11330.000000  1.133000e+04
# mean   94116.912004  3.689973e+07
# std        9.400877  7.800741e+07
# min    94102.000000  1.506329e+07
# 25%    94110.000000  1.510847e+07
# 50%    94115.000000  1.515697e+07
# 75%    94123.000000  5.970040e+07
# max    94158.000000  2.146999e+09

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'address', 'z_address', 'bathrooms', 'bedrooms',
#        'finishedsqft', 'lastsolddate', 'lastsoldprice', 'latitude',
#        'longitude', 'neighborhood', 'totalrooms', 'usecode', 'yearbuilt',
#        'zestimate', 'zindexvalue', 'zipcode', 'zpid'],
#       dtype='object')

# %%
cols = ['Unnamed: 0', 'bathrooms', 'bedrooms',
       'finishedsqft', 'lastsoldprice', 'latitude',
       'longitude', 'totalrooms','yearbuilt','zipcode']
cols2 = ['Unnamed: 0', 'bathrooms', 'bedrooms',
       'finishedsqft', 'latitude',
       'longitude', 'totalrooms','yearbuilt','zipcode']

# %%
data.dropna().shape
# Out:
# (11108, 18)

# %%
# -             = 0.8375491685999106, 0.607156739569225
# finishedsqft  = 0.8524615199933394, 0.5577844171230759
# long and lat  = 0.8517111453083177, 0.6874289038247563
# totalrooms    = 0.8598254992362179, 0.6426676296618906
# Out:
#   File "<ipython-input-14-f98496e9d777>", line 1
#     -             = 0.8375491685999106, 0.607156739569225
#                   ^
# SyntaxError: invalid syntax

# %%
get_score(data.dropna()[cols], data.dropna()['zestimate'])
# Out:
# 0.8375491685999527

# %%
get_score(data.dropna()[cols2], data.dropna()['zestimate'])
# Out:
# 0.6071567395692328

# %%
for_drop = ['Unnamed: 0', 'address', 'zindexvalue', 'zpid']
target = ['zestimate']

# %%
_ = get_value(data, 'finishedsqft', mode='linreg', value=0, columns_for_reg=['bathrooms', 'bedrooms', 'lastsoldprice','totalrooms'])

# %%
data['neighborhood'].value_counts().head()
# Out:
# Mission            540
# Bernal Heights     525
# South of Market    524
# South Beach        461
# Pacific Heights    439
# Name: neighborhood, dtype: int64

# %%
for i, el in data[data['latitude'].isna()].iterrows():
  data.loc[i, 'longitude'] = data[data['neighborhood'] == el['neighborhood']]['longitude'].mean()
  data.loc[i, 'latitude'] = data[data['neighborhood'] == el['neighborhood']]['latitude'].mean()

# %%
data[data.totalrooms - (data.bedrooms + data.bathrooms) < 0]
# Out:
#        Unnamed: 0                                  address  \
# 2               7          Address: 560 Missouri Street #B
# 4              11              Address: 3658 Folsom Street
# 39             74                Address: 2455 14th Avenue
# 46             93               Address: 784 Spruce Street
# 60            121            Address: 2017 Buchanan Street
# 94            253         Address: 701 Pennsylvania Avenue
# 97            256              Address: 164 Seville Street
# 98            257              Address: 145 Alpine Terrace
# 111           296          Address: 712 Dorado Terrace #53
# 113           298                Address: 4450 24th Street
# 121           310              Address: 17 San Andreas Way
# 122           313               Address: 319 Arleta Avenue
# 129           332             Address: 1423 Oakdale Avenue
# 142           384                Address: 2133 Pine Street
# 149           395            Address: 1546 McKinnon Avenue
# 166           427             Address: 2130 Quesada Avenue
# 188           480              Address: 1833 Laguna Street
# 209           540                    Address: 7 Lee Avenue
# 213           547                Address: 1765 15th Avenue
# 217           556  Address: 851 South Van Ness Avenue #104
# 218           557               Address: 54 Marston Avenue
# 221           560             Address: 304 Gold Mine Drive
# 235           589             Address: 638 19th Street #10
# 236           591               Address: 270 Nevada Street
# 242           602             Address: 1915 Diamond Street
# 296           733               Address: 130 Vienna Street
# 304           748        Address: 1080 Sutter Street #1001
# 307           753                Address: 221 Flood Avenue
# 318           770                  Address: 27 Gaviota Way
# 322           775             Address: 131 Brussels Street
# ...           ...                                      ...
# 10720       16693               Address: 444 Oak Street #A
# 10726       16702               Address: 156 Goethe Street
# 10736       16716                 Address: 574 Head Street
# 10743       16728          Address: 965 Folsom Street #206
# 10763       16753                Address: 1635 33rd Avenue
# 218                                   Sunnyside         7.0     SingleFamily
# 221                             Diamond Heights         7.0     SingleFamily
# 235               Central Waterfront - Dogpatch         5.0      Condominium
# 236                              Bernal Heights         6.0     SingleFamily
# 242                                   Glen Park         6.0     SingleFamily
# 296                                   Excelsior         6.0     SingleFamily
# 304                                    Downtown         4.0      Condominium
# 307                                   Sunnyside         7.0     SingleFamily
# 318                               Miraloma Park         5.0     SingleFamily
# 322                                     Portola         6.0     SingleFamily
# ...                                         ...         ...              ...
# 10720                              Hayes Valley         5.0      Condominium
# 10726                             Outer Mission         5.0     SingleFamily
# 10736                         Ingleside Heights         4.0     SingleFamily
# 10743                           South of Market         2.0      Condominium
# 10763                            Central Sunset         7.0     SingleFamily
# 10807                                  Nob Hill         5.0      Condominium
# 10820                                   Bayview         7.0     SingleFamily
# 10821                                   Bayview         2.0      Condominium
# 10848                             Lone Mountain         7.0      Condominium
# 10849                          Central Richmond         7.0     SingleFamily
# 10881                                      Lake         6.0     SingleFamily
# 10885                               West Portal         5.0     SingleFamily
# 10889                               South Beach         3.0      Condominium
# 10905                              Hayes Valley         5.0      Condominium
# 10913                            Bernal Heights         4.0     SingleFamily
# 10924                              Inner Sunset         7.0     SingleFamily
# 10954                               West Portal         6.0     SingleFamily
# 10963  Eureka Valley - Dolores Heights - Castro         5.0      Condominium
# 11026                           South of Market         4.0      Condominium
# 11031                           Pacific Heights         6.0      Condominium
# 11062                                Noe Valley         6.0     SingleFamily
# 11114                                  Downtown         4.0     SingleFamily
# 11120                                Noe Valley         5.0     SingleFamily
# 11125                       Golden Gate Heights         5.0     SingleFamily
# 11226                                 Oceanview         5.0     SingleFamily
# 11255                              Potrero Hill         6.0      Condominium
# 11257                            Bernal Heights         4.0     SingleFamily
# 11292                               West Portal         5.0     SingleFamily
# 11299                             Lone Mountain        10.0  MultiFamily2To4
# 11313                     Lower Pacific Heights         7.0      Condominium
#
#        yearbuilt  zestimate zindexvalue  zipcode          zpid
# 2         2003.0  1708594.0   1,277,600  94107.0  6.497285e+07
# 4         1900.0  1918539.0   1,248,000  94110.0  1.516198e+07
# 39        1932.0  1195679.0   1,565,000  94116.0  1.512286e+07
# 46        1927.0  1524759.0   1,447,700  94118.0  1.508382e+07
# 60        1890.0  3032479.0   1,178,700  94115.0  2.169907e+07
# 94        1999.0   905401.0   1,277,600  94107.0  5.877020e+07
# 97        1924.0   917185.0     823,000  94112.0  1.517815e+07
# 98        2007.0  4791629.0   1,500,900  94117.0  8.924057e+07
# 111       1985.0   773173.0   1,378,600  94112.0  1.514233e+07
# 113       1900.0  2088377.0   1,782,000  94114.0  1.513224e+07
# 121       1937.0  4381290.0   3,056,100  94127.0  1.513819e+07
# 122       1989.0   862924.0     707,100  94134.0  1.517405e+07
# 129       1938.0   601102.0     731,900  94124.0  1.515649e+07
# 142       1900.0  5461047.0   1,178,700  94115.0  1.507536e+07
# 149       1940.0   735339.0     731,900  94124.0  1.515596e+07
# 166       1944.0   676584.0     736,700  94124.0  1.515672e+07
#
# [782 rows x 18 columns]

# %%
get_score(data.dropna()[['finishedsqft']], data.dropna()['zestimate'])
# Out:
# 0.6064430886914685

# %%
_ = get_value(data, 'totalrooms', mode='linreg', value=0, columns_for_reg=['bathrooms', 'bedrooms', 'lastsoldprice','finishedsqft'])

# %%
data['totalrooms'] = data['totalrooms'].apply(lambda x: round(x))

# %%
data['usecode'].value_counts(dropna=False)
# Out:
# SingleFamily        5785
# Condominium         4782
# MultiFamily2To4      484
# Duplex               146
# Townhouse             66
# NaN                   40
# Miscellaneous         17
# Cooperative            3
# Apartment              3
# MultiFamily5Plus       2
# Mobile                 2
# Name: usecode, dtype: int64

# %%
_ = get_value(data, 'usecode', mode='value', value='other')

# %%
data.head(2)
# Out:
#    Unnamed: 0                             address                  z_address  \
# 0           2  Address: 1160 Mission Street #2007  1160 Mission St UNIT 2007
# 1           5       Address: 260 King Street #475       260 King St UNIT 475
#
#    bathrooms  bedrooms  finishedsqft lastsolddate  lastsoldprice   latitude  \
# 0        2.0       2.0        1043.0   02/17/2016      1300000.0  37.778705
# 1        1.0       1.0         903.0   02/17/2016       750000.0  37.777641
#
#     longitude     neighborhood  totalrooms      usecode  yearbuilt  zestimate  \
# 0 -122.412635  South of Market           4  Condominium     2007.0  1167508.0
# 1 -122.393417  South of Market           3  Condominium     2004.0   823719.0
#
#   zindexvalue  zipcode        zpid
# 0     975,700  94103.0  83152781.0
# 1     975,700  94107.0  69819817.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11330 entries, 0 to 11329
# Data columns (total 18 columns):
# Unnamed: 0       11330 non-null int64
# address          11330 non-null object
# z_address        11330 non-null object
# bathrooms        11330 non-null float64
# bedrooms         11330 non-null float64
# finishedsqft     11330 non-null float64
# lastsolddate     11330 non-null object
# lastsoldprice    11330 non-null float64
# latitude         11330 non-null float64
# longitude        11330 non-null float64
# neighborhood     11330 non-null object
# totalrooms       11330 non-null int64
# usecode          11330 non-null object
# yearbuilt        11330 non-null float64
# zestimate        11330 non-null float64
# zindexvalue      11330 non-null object
# zipcode          11330 non-null float64
# zpid             11330 non-null float64
# dtypes: float64(10), int64(2), object(6)
# memory usage: 1.6+ MB

# %%
#data.to_csv('new_data.csv')

# %% [markdown]
#  ## Вторая часть

# %%
data = pd.read_csv('new_data.csv')

# %%
def get_one_hot(X, cols):
    for each in cols:
        dummies = pd.get_dummies(X[each], prefix=each, drop_first=False)
        X = pd.concat([X, dummies], axis=1)
    return X

def get_woe_v1(X, col, target_col):
    all_one = X[col].value_counts() / X[col].value_counts()
    all_good = len(X[X[target_col] == 1][col])
    all_bad = len(X[X[target_col] == 0][col])
    odds_series = (
        (((all_one*X[df_train[target_col] == 1][col].value_counts()).fillna(0)+0.5)/all_good)
        /
        (((all_one*X[X[target_col] == 0][col].value_counts()).fillna(0)+0.5)/all_bad)
    )
    category_woe_dict = np.log(odds_series).to_dict()
    X[col + '_woe'] = X[col].apply(category_woe_dict.get)
    return X

def get_woe_cols(X, cols, target_col):
    for col in cols:
        X = get_woe_v1(X, col, target_col)
    return X
